# %% [markdown]
# <font style='font-size:1.5em'>**👨🏻‍🏫 Week 04 lecture – Web Scraping** </font>
#
# <font style='font-size:1.2em'>DS105W – Data for Data Science</font>
#
# **AUTHORS:**  Dr. [Jon Cardoso-Silva](https://jonjoncardoso.github.io)
#
# **DEPARTMENT:** [LSE Data Science Institute](https://lse.ac.uk/dsi)
#
# **OBJECTIVE**: Learn how to collect data from the Web using Python packages
#
# **LAST REVISION:** 8 February 2024

# %% [markdown]
# ---
#
# # Part I: ⚙️ The setup
#
# You will need to install the requests and Scrapy packages in order to complete this lab. I will assume you have configured the virtual environment for this course as follows.
#
#
#
# Open the terminal (directly from within VS Code will be easier) and run each of the following commands:
#
#
# ```bash
# pip install pandas requests scrapy
# ```

# %%
import requests               # This is how we access the web
import pandas as pd           # This is how we work with data frames

from pprint import pprint     # Print things in a pretty way
from scrapy import Selector   # This is how we parse HTML

# %% [markdown]
# # Part II: Requesting a web page
#
#
# You might have heard of [CIVICA](https://www.civica.eu/who-we-are/about-civica/) before. It is a body that unites several European universities to collaborate in the areas of social sciences, humanities, business and public policy. CIVICA hosts [Data Science Seminar series](https://socialdatascience.network/index.html#schedule) that might be of interest to you. Today we will collect information on some of the seminars. Maybe you can use it in the future!
#
# **Our main task** is to create a 🐼 pandas data frame that would contain:
#
# 1. names of the seminars
# 2. names of speakers of those seminars
# 3. dates of the seminars
# 4. bios of the speakers from each individual event

# %% [markdown]
# ## 2.1. Request a website

# %%
# This is the address of the website we want to scrape
my_url = 'https://socialdatascience.network/index.html#schedule'

# We set a GET request to the website
response = requests.get(my_url)

# What is the response code?
response
# Out:
# <Response [200]>

# %% [markdown]
# **📜 Other possible responses**
#
# The response code is standard way of communicating the status of a request. There are many other possible responses:
#
# - **200** OK
# - **204** No Content
# - **400** Bad Request
# - **401** Unauthorized
# - **402** Payment Required
# - **403** Forbidden
# - **404** Not Found
# - **500** Internal Server Error
# - **502** Bad Gateway
#
# 🗣️ **CLASSROOM DISCUSSION:** Have you ever encountered any of these responses when browsing the Web on your browser? Where? What did you do about it?
#
#
# You can find a full list [here](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status).

# %% [markdown]
# ## 2.2. A closer look at the response
#
# What else is stored in the `response` object?

# %%
# The vars function returns all attributes of an object, along with their values
# You will see that it is essentially just a dictionary
vars(response)
# Out:
# {'_content': b'<!DOCTYPE html>\r\n<html lang="en">\r\n\r\n<head>\r\n  <meta charset="utf-8">\r\n  <title>CIVICA Data Science Seminar</title>\r\n  <meta content="width=device-width, initial-scale=1.0" name="viewport">\r\n  <meta content="CIVICA Data Science Seminar" name="keywords">\r\n  <meta content="A series of data science workshops and seminars" name="description">\r\n\r\n  <!-- Favicons -->\r\n  <link href="img/c-favicon.png" rel="icon">\r\n  <link href="img/apple-touch-icon.png" rel="apple-touch-icon">\r\n\r\n  <!-- Google Fonts -->\r\n  <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,700,700i|Raleway:300,400,500,700,800" rel="stylesheet">\r\n\r\n  <!-- Bootstrap CSS File -->\r\n  <link href="lib/bootstrap/css/bootstrap.min.css" rel="stylesheet">\r\n\r\n  <!-- Libraries CSS Files -->\r\n  <link href="lib/font-awesome/css/font-awesome.min.css" rel="stylesheet">\r\n  <link href="lib/animate/animate.min.css" rel="stylesheet">\r\n  <link href="lib/venobox/venobox.css" rel="stylesheet">\r\n  <link href="lib/owlcarousel/assets/owl.carousel.min.css" rel="stylesheet">\r\n\r\n  <!-- Main Stylesheet File -->\r\n  <link href="css/style.css" rel="stylesheet">\r\n  <link href="lib/aos/aos.css">\r\n\r\n<!--   Mailchimp service -->\r\n  <link href="//cdn-images.mailchimp.com/embedcode/classic-10_7.css" rel="stylesheet" type="text/css">\r\n\r\n\r\n</head>\r\n\r\n  <!-- Global site tag (gtag.js) - Google Analytics -->\r\n  <script async src="https://www.googletagmanager.com/gtag/js?id=G-Q9R21L0VJH"></script>\r\n  <script>\r\n    window.dataLayer = window.dataLayer || [];\r\n    function gtag(){dataLayer.push(arguments);}\r\n    gtag(\'js\', new Date());\r\n\r\n    gtag(\'config\', \'G-Q9R21L0VJH\');\r\n  </script>\r\n\r\n<body>\r\n\r\n  <!--==========================\r\n    Header\r\n  ============================-->\r\n  <header id="header">\r\n    <div class="container">\r\n\r\n      <div id="logo" class="pull-left">\r\n        <!-- Uncomment below if you prefer to use a text logo -->\r\n        <!-- <h1><a href="#main">C<span>o</span>nf</a></h1>-->\r\n        <a href="#intro" class="scrollto"><img src="img/logo.png" alt="" title=""></a>\r\n      </div>\r\n\r\n      <nav id="nav-menu-container">\r\n        <ul class="nav-menu">\r\n          <li class="menu-active"><a href="#intro">Home</a></li>\r\n          <li><a href="#about">About</a></li>\r\n<!--           <li><a href="#speakers">Speakers</a></li>\r\n -->          <li><a href="#schedule">Schedule</a></li>\r\n          <li><a href="#supporters">Partner Institutions</a></li>\r\n          <li><a href="summerschool.html">Summer School</a></li>\r\n          <li><a href="#gallery">Gallery</a></li>\r\n          <li><a href="#contact">Contact</a></li>\r\n        </ul>\r\n      </nav><!-- #nav-menu-container -->\r\n    </div>\r\n  </header><!-- #header -->\r\n\r\n  <!--==========================\r\n    Intro Section\r\n  ============================-->\r\n  <section id="intro">\r\n    <div class="intro-container wow fadeIn">\r\n      <h1 class="mb-4 pb-0">CIVICA<br><span>Data Science</span> Seminar Series</h1>\r\n<!--       <p class="mb-4 pb-0">10-12 December, Downtown Conference Center, New York</p>\r\n -->      \r\n<!--  <a href="https://www.youtube.com/watch?v=jDDaplaOz7Q" class="venobox play-btn mb-4" data-vbtype="video"\r\n        data-autoplay="true"></a>\r\n -->\r\n\r\n\r\n                <!-- Currently only supports Web version for AI personal assistant, because of the precision issue (16 vs 32 bit) using WebGL backend and CPU backend is too slow.  -->\r\n                <br>\r\n                <div style="width: 500px">\r\n                <input autocomplete="off" type="text" placeholder="What is this seminar series?" id="myInput" class="form-control" style="background: transparent"/></div>\r\n                <br>\r\n                <div id="first_assistant_desc" style="color: white"><i>Greetings! I am a personal AI assistant. I am built with a pre-t ...
#  '_content_consumed': True,
#  '_next': None,
#  'status_code': 200,
#  'headers': {'Connection': 'keep-alive', 'Content-Length': '18651', 'Server': 'GitHub.com', 'Content-Type': 'text/html; charset=utf-8', 'Last-Modified': 'Tue, 06 Feb 2024 10:58:31 GMT', 'Access-Control-Allow-Origin': '*', 'ETag': 'W/"65c210d7-1c1c6"', 'expires': 'Thu, 08 Feb 2024 15:18:24 GMT', 'Cache-Control': 'max-age=600', 'Content-Encoding': 'gzip', 'x-proxy-cache': 'MISS', 'X-GitHub-Request-Id': 'A5B0:FE42:23F7EF4:24BA65A:65C4EE68', 'Accept-Ranges': 'bytes', 'Date': 'Thu, 08 Feb 2024 17:36:59 GMT', 'Via': '1.1 varnish', 'Age': '48', 'X-Served-By': 'cache-lcy-eglc8600065-LCY', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1707413819.335317,VS0,VE1', 'Vary': 'Accept-Encoding', 'X-Fastly-Request-ID': '97ec27249c9ebced1297496006308adcd2b836d5'},
#  'raw': <urllib3.response.HTTPResponse at 0x18ea64c2a40>,
#  'url': 'https://socialdatascience.network/index.html#schedule',
#  'encoding': 'utf-8',
#  'history': [],
#  'reason': 'OK',
#  'cookies': <RequestsCookieJar[]>,
#  'elapsed': datetime.timedelta(microseconds=266931),
#  'request': <PreparedRequest [GET]>,
#  'connection': <requests.adapters.HTTPAdapter at 0x18ea7017950>}

# %% [markdown]
# 🗣️ **CLASSROOM DISCUSSION:**
#
# You have already looked at `response.status_code`. But what do you think the following attributes of the `response` object are?
#
# - `response.headers`
# - `response.cookies`
# - `response.content`
#
# Feel free to open a new chunk of code below and explore these attributes.

# %% [markdown]
# But encoding is not the only **metadata** we can get from the response. Let's take a look at all the headers:

# %%
# Headers are metadata about the response
print(response.headers)
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '18651', 'Server': 'GitHub.com', 'Content-Type': 'text/html; charset=utf-8', 'Last-Modified': 'Tue, 06 Feb 2024 10:58:31 GMT', 'Access-Control-Allow-Origin': '*', 'ETag': 'W/"65c210d7-1c1c6"', 'expires': 'Sat, 10 Feb 2024 18:37:07 GMT', 'Cache-Control': 'max-age=600', 'Content-Encoding': 'gzip', 'x-proxy-cache': 'MISS', 'X-GitHub-Request-Id': '78A4:4AF44:492A5DE:4AC7DA0:65C7BFFB', 'Accept-Ranges': 'bytes', 'Date': 'Sat, 10 Feb 2024 18:27:08 GMT', 'Via': '1.1 varnish', 'Age': '0', 'X-Served-By': 'cache-lhr7331-LHR', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'X-Timer': 'S1707589628.893803,VS0,VE126', 'Vary': 'Accept-Encoding', 'X-Fastly-Request-ID': '3fea3040d5bff08ef65e47b842101a93defded27'}

# %% [markdown]
# We could choose to manipulate the headers above as a `pd.Series`:

# %%
pd.Series(response.headers)
# Out:
# Connection                                                   keep-alive
# Content-Length                                                    18651
# Server                                                       GitHub.com
# Content-Type                                   text/html; charset=utf-8
# Last-Modified                             Tue, 06 Feb 2024 10:58:31 GMT
# Access-Control-Allow-Origin                                           *
# ETag                                                 W/"65c210d7-1c1c6"
# expires                                   Thu, 08 Feb 2024 15:18:24 GMT
# Cache-Control                                               max-age=600
# Content-Encoding                                                   gzip
# x-proxy-cache                                                      MISS
# X-GitHub-Request-Id                  A5B0:FE42:23F7EF4:24BA65A:65C4EE68
# Accept-Ranges                                                     bytes
# Date                                      Thu, 08 Feb 2024 17:36:59 GMT
# Via                                                         1.1 varnish
# Age                                                                  48
# X-Served-By                                   cache-lcy-eglc8600065-LCY
# X-Cache                                                             HIT
# X-Cache-Hits                                                          1
# X-Timer                                      S1707413819.335317,VS0,VE1
# Vary                                                    Accept-Encoding
# X-Fastly-Request-ID            97ec27249c9ebced1297496006308adcd2b836d5
# dtype: object

# %% [markdown]
# Let me know you what is in the object `response` by printing it.

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="utf-8">
#   <title>CIVICA Data Science Seminar</title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#   <meta content="CIVICA Data Science Seminar" name="keywords">
#   <meta content="A series of data science workshops and seminars" name="description">
#
#   <!-- Favicons -->
#   <link href="img/c-favicon.png" rel="icon">
#   <link href="img/apple-touch-icon.png" rel="apple-touch-icon">
#
#   <!-- Google Fonts -->
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,700,700i|Raleway:300,400,500,700,800" rel="stylesheet">
#
#   <!-- Bootstrap CSS File -->
#   <link href="lib/bootstrap/css/bootstrap.min.css" rel="stylesheet">
#
#   <!-- Libraries CSS Files -->
#   <link href="lib/font-awesome/css/font-awesome.min.css" rel="stylesheet">
#   <link href="lib/animate/animate.min.css" rel="stylesheet">
#   <link href="lib/venobox/venobox.css" rel="stylesheet">
#   <link href="lib/owlcarousel/assets/owl.carousel.min.css" rel="stylesheet">
#
#   <!-- Main Stylesheet File -->
#   <link href="css/style.css" rel="stylesheet">
#   <link href="lib/aos/aos.css">
#
# <!--   Mailchimp service -->
#   <link href="//cdn-images.mailchimp.com/embedcode/classic-10_7.css" rel="stylesheet" type="text/css">
#
#
# </head>
#
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async src="https://www.googletagmanager.com/gtag/js?id=G-Q9R21L0VJH"></script>
#   <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'G-Q9R21L0VJH');
#   </script>
#
# <body>
#
#   <!--==========================
#     Header
#   ============================-->
#   <header id="header">
#     <div class="container">
#
#       <div id="logo" class="pull-left">
#         <!-- Uncomment below if you prefer to use a text logo -->
#         <!-- <h1><a href="#main">C<span>o</span>nf</a></h1>-->
#         <a href="#intro" class="scrollto"><img src="img/logo.png" alt="" title=""></a>
#       </div>
#
#       <nav id="nav-menu-container">
#         <ul class="nav-menu">
#           <li class="menu-active"><a href="#intro">Home</a></li>
#           <li><a href="#about">About</a></li>
# <!--           <li><a href="#speakers">Speakers</a></li>
#  -->          <li><a href="#schedule">Schedule</a></li>
#           <li><a href="#supporters">Partner Institutions</a></li>
#           <li><a href="summerschool.html">Summer School</a></li>
#           <li><a href="#gallery">Gallery</a></li>
#           <li><a href="#contact">Contact</a></li>
#         </ul>
#       </nav><!-- #nav-menu-container -->
#     </div>
#   </header><!-- #header -->
#
#   <!--==========================
#     Intro Section
#   ============================-->
#   <section id="intro">
#     <div class="intro-container wow fadeIn">
#       <h1 class="mb-4 pb-0">CIVICA<br><span>Data Science</span> Seminar Series</h1>
# <!--       <p class="mb-4 pb-0">10-12 December, Downtown Conference Center, New York</p>
#  -->
# <!--  <a href="https://www.youtube.com/watch?v=jDDaplaOz7Q" class="venobox play-btn mb-4" data-vbtype="video"
#         data-autoplay="true"></a>
#  -->
#
#
#                 <!-- Currently only supports Web version for AI personal assistant, because of the precision issue (16 vs 32 bit) using WebGL backend and CPU backend is too slow.  -->
#                 <br>
#                 <div style="width: 500px">
#                 <input autocomplete="off" type="text" placeholder="What is this seminar series?" id="myInput" class="form-control" style="background: transparent"/></div>
#                 <br>
#                 <div id="first_assistant_desc" style="color: white"><i>Greetings! I am a personal AI assistant. I am built with a pre-trained Universal Sentence Encoder model from TensorFlow-js. <br>Please ask me anything about the event with a complete sentence (e.g: "What is CIVICA?") and I'll try my best to answer your queries.</i></div>
#                 <div class="lds-ellipsis" id="loading_dots"><div></div><div></div><div></div><div></div></div>
#                 <strong><div id="output"></div></strong>
#
#                 <br>
#
# <!--       <a href="#about" class="about-btn scrollto">About The Seminar Series</a>
#  -->
#          <a href="#schedule"><div class="text-center"><button type="submit" class="register-button">Register Now</button></div></a>
#
# </div>
#   </section>
#
#   <main id="main">
#
#     <!--==========================
#       About Section
#     ============================-->
#     <section id="about">
#       <div class="container">
#         <div class="row">
#           <div class="col-lg-6">
#             <h3>About The Series</h3>
#             <p>The CIVICA Data Science seminar series is the interdisciplinary forum of the CIVICA European University of Social Sciences, and alliance of eight leading higher education and research institutions. We foster a community of researchers, practitioners, and policy makers working to address complex societal challenges through the use of novel methodological and data-driven approaches, drawing from machine learning and quantitative methods from biology, sociology, political sciences, economics, and physics among others disciplines.
# <!--             <p>The Data Science Seminar series is a multi-disciplinary series focused on applications and methodologies of data science for the social, political, and economic world. Its aim is to allow researchers to share original, new work or work in progress in order to get methodological or technical comments and suggestions.
#  -->              <br>
#               <br>
#             Shared among the partner institutions of the CIVICA network, this series directly addresses the data science research stream of the CIVICA initiative.</p>
#           </div>
#           <div class="col-lg-3">
#             <h3>Where</h3>
#             <p>During COVID19 travel restrictions, the series will take place online (e.g. using MS Teams or Zoom).</p>
#           </div>
#           <div class="col-lg-3">
#             <h3>When</h3>
#             <p>The seminar series will start with regular bi-weekly slots (Wednesdays every other week at 16.00 Central European Time) across regular academic year. The number of meetings can be expanded with the increase of partner institutions.</p>
#           </div>
#         </div>
#       </div>
#     </section>
#
#
#     <!--==========================
#       Schedule Section
#     ============================-->
#     <section id="schedule" class="section-with-bg">
#       <div class="container wow fadeInUp">
#         <div class="section-header">
#           <h2>Seminar Schedule</h2>
#           <p>Here is our tentative seminar series schedule in 2021</p>
# <!--           <a href="form.html"><div class="text-center"><button type="submit" class="register-button">Register Now</button></div></a>
#  -->
#         </div>
#
#         <div class="row" data-aos="fade-up" data-aos-delay="200">
#           <div class="col-lg-12 d-flex justify-content-center">
#             <ul id="portfolio-flters">
#               <li data-filter="*" class="filter-active">All</li>
#               <li data-filter=".filter-spring">Spring 2021</li>
#               <li data-filter=".filter-fall">Fall 2021</li>
#               <li data-filter=".filter-spring2022">Spring 2022</li>
#               <li data-filter=".filter-fall2022">Fall 2022</li>
#               <li data-filter=".filter-spring2023">Spring 2023</li>
#               <li data-filter=".filter-fall2023">Fall 2023</li>
#               <li data-filter=".filter-spring2024">Spring 2024</li>
#             </ul>
#           </div>
#         </div>
#
#
#
#
#
# <div class="card-deck row" data-aos="fade-up" data-aos-delay="400">
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2024">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2024/sess1.html"><img class="card-img-top" src="spring2024/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="spring2024/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2024/sess1.html"><h6 class="card-title">Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Tiago Ventura, Georgetown University <br> Date: Wednesday, 07 February 2024</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2024/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2023/sess4.html"><img class="card-img-top" src="fall2023/visuals/sess4/sess4.png" alt="data science"></a>
#       <a href="fall2023/sess4.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2023/sess4.html"><h6 class="card-title">Promoting the systematic use of real-world data and real-world evidence for digital health technologies across Europe: A consensus framework</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Divya Srivastava, LSE <br> Date: Wednesday, 22 November 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2023/sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2023/sess3.html"><img class="card-img-top" src="fall2023/visuals/sess3/sess3.png" alt="data science"></a>
#       <a href="fall2023/sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2023/sess3.html"><h6 class="card-title">Data science for the Sustainable Development Goals: the case of food security</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Elisa Omodei, CEU <br> Date: Wednesday, 18 October 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2023/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2023/sess2.html"><img class="card-img-top" src="fall2023/visuals/sess2/sess2.png" alt="data science"></a>
#       <a href="fall2023/sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2023/sess2.html"><h6 class="card-title">CentralBankRoBERTa: A Fine-Tuned Large Language Model for Central Bank Communications</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Moritz Pfeifer & Vincent Philipp Marohl <br> Date: Wednesday, 27 September 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2023/sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2023/sess1.html"><img class="card-img-top" src="fall2023/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="fall2023/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2023/sess1.html"><h6 class="card-title">The Evolution of the Climate Discourse on Twitter: Polarization, Hypocrisy, and the Musk Takeover</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Max Falkenberg <br> Date: Wednesday, 13 September 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2023/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="card-deck row" data-aos="fade-up" data-aos-delay="400">
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess7.html"><img class="card-img-top" src="spring2023/visuals/sess7/sess7.png" alt="data science"></a>
#       <a href="spring2023/sess7.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess7.html"><h6 class="card-title">The Handbook of Computational Social Science for Policy</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Eleonora Bertoni <br> Date: Wednesday, 31 May 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess7.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess6.html"><img class="card-img-top" src="spring2023/visuals/sess6/sess6.png" alt="data science"></a>
#       <a href="spring2023/sess6.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess6.html"><h6 class="card-title">Artificial Intelligence, Algorithmic Recommendations and Competition</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Giacomo Calzolari <br> Date: Wednesday, 03 May 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess6.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess5.html"><img class="card-img-top" src="spring2023/visuals/sess5/sess5.png" alt="data science"></a>
#       <a href="spring2023/sess5.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess5.html"><h6 class="card-title">Exploring A New Model of Industry/Academic Collaboration: the U.S. 2020 Facebook and Instagram Election Study</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Pablo Barberá <br> Date: Wednesday, 19 April 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess5.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess4.html"><img class="card-img-top" src="spring2023/visuals/sess4/sess4.png" alt="data science"></a>
#       <a href="spring2023/sess4.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess4.html"><h6 class="card-title">Using Multimodal Neural Networks to Better Understand How Voters Process Audiovisual Information</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Bryce Jensen Dietrich <br> Date: Wednesday, 22 March 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess3.html"><img class="card-img-top" src="spring2023/visuals/sess3/sess3.png" alt="data science"></a>
#       <a href="spring2023/sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess3.html"><h6 class="card-title">Models, mathematics, and data science: how to make sure we're answering the right questions</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Erica Thompson <br> Date: Wednesday, 08 March 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="polarisation/2023.html"><img class="card-img-top" src="polarisation/assets/img/poster.jpeg" alt="data science"></a>
#       <a href="polarisation/2023.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="polarisation/2023.html"><h6 class="card-title">CIVICA Conference on European Polarisation</h6></a>
#       <!--Text-->
#       <p class="card-text">Full day event <br> Date: Wednesday, 15 February 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="polarisation/2023.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess2.html"><img class="card-img-top" src="spring2023/visuals/sess2/sess2.png" alt="data science"></a>
#       <a href="spring2023/sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess2.html"><h6 class="card-title">New Faces of Bias in Online Platforms</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Aniko Hannak <br> Date: Wednesday, 08 February 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess1.html"><img class="card-img-top" src="spring2023/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="spring2023/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess1.html"><h6 class="card-title">Introducing the Online Harms Observatory: AI powered mapping of online abuse in real-time</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Pica Johnsson <br> Date: Wednesday, 11 January 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2022/sess3.html"><img class="card-img-top" src="fall2022/visuals/sess3/sess3.png" alt="data science"></a>
#       <a href="fall2022/sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2022/sess3.html"><h6 class="card-title">Using Open Source Data Streams and Surveys to Improve Our Understanding of Elections</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Lisa Singh <br> Date: Wednesday, 02 November 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2022/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2022/sess2.html"><img class="card-img-top" src="fall2022/visuals/sess2/sess2.png" alt="data science"></a>
#       <a href="fall2022/sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2022/sess2.html"><h6 class="card-title">Does Epistemic Vice Explain Corporate Misconduct?</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Marco Meyer <br> Date: Wednesday, 19 October 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2022/sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess10.html"><img class="card-img-top" src="spring2022/visuals/sess10/sess10.png" alt="data science"></a>
#       <a href="spring2022/sess10.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess10.html"><h6 class="card-title">Becoming a data scientist: what it means to put data to work</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Anne Beaulieu <br> Date: Wednesday, 14 September 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess10.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess9.html"><img class="card-img-top" src="spring2022/visuals/sess9/sess9.png" alt="data science"></a>
#       <a href="spring2022/sess9.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess9.html"><h6 class="card-title">The Making of a French Migration Crisis</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Michelle Reddy & Dr. Hélène Thiollet <br> Date: Wednesday, 15 June 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess9.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess8.html"><img class="card-img-top" src="spring2022/visuals/sess8/sess8.png" alt="data science"></a>
#       <a href="spring2022/sess8.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess8.html"><h6 class="card-title">A New Approach to Visualizing Spatial Exposure Data for Comparing Earthquakes</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Stephanie Lackner <br> Date: Wednesday, 01 June 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess8.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess7.html"><img class="card-img-top" src="spring2022/visuals/sess7/sess7.png" alt="data science"></a>
#       <a href="spring2022/sess7.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess7.html"><h6 class="card-title">Modeling Sustainable Development from the Bottom Up</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Omar A. Guerrero <br> Date: Wednesday, 04 May 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess7.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess6.html"><img class="card-img-top" src="spring2022/visuals/sess6/sess6.png" alt="data science"></a>
#       <a href="spring2022/sess6.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess6.html"><h6 class="card-title">Internet Communities and the French Presidential Election</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. David Chavalarias <br> Date: Wednesday, 20 April 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess6.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess5.html"><img class="card-img-top" src="spring2022/visuals/sess5/sess5.png" alt="data science"></a>
#       <a href="spring2022/sess5.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess5.html"><h6 class="card-title">The Science of Success: Quantifying Outcomes in Social System</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Laszlo Barabasi <br> Date: Wednesday, 09 March 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess5.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess4.html"><img class="card-img-top" src="spring2022/visuals/sess4/sess4.png" alt="data science"></a>
#       <a href="spring2022/sess4.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess4.html"><h6 class="card-title">Embedding Regression: Models for Context-Specific Description and Inference</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Arthur Spirling <br>Date: Wednesday, 23 February 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess3.html"><img class="card-img-top" src="spring2022/visuals/sess3/sess3.png" alt="data science"></a>
#       <a href="spring2022/sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess3.html"><h6 class="card-title">Information and Irregular Migration: Evidence from a Field Experiment in Nigeria</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Alexandra Scacco <br> Date: Wednesday, 09 February 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess2.html"><img class="card-img-top" src="spring2022/visuals/sess2/sess2.png" alt="data science"></a>
#       <a href="spring2022/sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess2.html"><h6 class="card-title">Adjusting for Confounding with Text Matching</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Margaret Roberts <br>Date: Wednesday, 26 January 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess1.html"><img class="card-img-top" src="spring2022/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="spring2022/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess1.html"><h6 class="card-title">What is Data Feminist?</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Lauren Klein <br>Date: Wednesday, 12 January 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2021/sess7.html"><img class="card-img-top" src="fall2021/visuals/sess7/sess7.png" alt="data science"></a>
#       <a href="fall2021/sess7.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess7.html"><h6 class="card-title">The Principles of Collective Learning</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Cesar A. Hidalgo <br> Date: Wednesday, 1 December 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess7.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2021/sess5.html"><img class="card-img-top" src="fall2021/visuals/sess5/sess5.png" alt="data science"></a>
#       <a href="fall2021/sess5.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess5.html"><h6 class="card-title">More Than Words: How Political Rhetoric Shapes Voters' Affect and Evluation</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Christopher Lucas <br> Date: Wednesday, 3 November 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess5.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2021/sess4.html"><img class="card-img-top" src="fall2021/visuals/sess4/sess4.png" alt="data science"></a>
#       <a href="fall2021/sess4.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess4.html"><h6 class="card-title">Serendipity or Confinement? Deconstructing Algorithmic Recommendation</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Camille Roth <br>Date: Wednesday, 20 October 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="bg-image hover-overlay ripple shadow-1-strong rounded"
#   data-mdb-ripple-color="light">
#       <a href="fall2021/sess3.html">
# <img class="card-img-top" src="fall2021/visuals/sess3/sess3.png"></a>
#
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess3.html"><h6 class="card-title">Framing a Protest: Determinants and Effects of Visual Frames</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Michelle Torrest <br>Date: Wednesday, 06 October 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess9.html"><img class="card-img-top" src="seminar-sessions/sess9/sess9.png" alt="data science"></a>
#       <a href="sess9.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess9.html"><h6 class="card-title">Understanding Beautiful Places with AI</h6></a>
#       <!--Text-->
#       <p>Speaker: Prof. Suzy Moat <br>Date: Wednesday, 22 September, 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess9.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#
#   <!-- Card -->
#
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2021/sess1.html"><img class="card-img-top" src="fall2021/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="fall2021/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess1.html"><h6 class="card-title">Incentives and Covid-19 Vaccination Uptake</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Macartan Humphreys<br>Date: Wednesday, 08 September 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="bg-image hover-overlay ripple shadow-1-strong rounded"
#   data-mdb-ripple-color="light ">
#       <a href="sess7.html">
# <img class="card-img-top" src="img/events/sess7/sess7.png"></a>
#
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess7.html"><h6 class="card-title">The Art of Quantitative Editing</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Laura Bronner<br>Date: Wednesday, 02 June 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess7.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess6.html"><img class="card-img-top" src="img/events/sess6/sess6.png" alt="data science"></a>
#       <a href="sess6.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess6.html"><h6 class="card-title">Breaking the Social Media Prism</h6></a>
#       <!--Text-->
#       <p>Speaker: Chris Bail<br>Date: Wednesday, 19 May, 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess6.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess5.html"><img class="card-img-top" src="img/events/sess5/sess5.png" alt="data science"></a>
#       <a href="sess5.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess5.html"><h6 class="card-title">Using Public Video Cameras to Detect Racial Distancing on City Streets</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Melissa Sands <br>Date: Wednesday, 05 May 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess5.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="bg-image hover-overlay ripple shadow-1-strong rounded"
#   data-mdb-ripple-color="light">
#       <a href="sess4.html">
#   <img class="card-img-top" src="img/events/sess4/fakenews.png"></a>
#
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess4.html"><h6 class="card-title">How to Detect Fake News Before It Is Written</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Preslav Nakov<br>Date: Wednesday, 21 April 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess3.html"><img class="card-img-top" src="img/events/sess3/negotiating.png" alt="data science"></a>
#       <a href="sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess3.html"><h6 class="card-title">Negotiating with AI: Fairness in the Labor Market</h6></a>
#       <!--Text-->
#       <p>Speaker: Prof. Christo Wilson<br>Date: Wednesday, 07 April, 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess2.html"><img class="card-img-top" src="img/events/sess2/tracking.png" alt="data science"></a>
#       <a href="sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess2.html"><h6 class="card-title">Tracking Covid-19 with the Financial Times</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: John Burn-Murdoch<br>Date: Wednesday, 24 March 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="bg-image hover-overlay ripple shadow-1-strong rounded"
#   data-mdb-ripple-color="light">
#       <a href="sess1.html">
# <img class="card-img-top" src="img/events/sess1/police.png"></a>
#
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess1.html"><h6 class="card-title">Police Diversity to Prevent Violence: Does It Work?</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Roman Rivera<br>Date: Wednesday, 17 March 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <!-- Card deck -->
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="launch.html"><img class="card-img-top" src="img/events/launch.png" alt="data science"></a>
#       <a href="launch.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="launch.html"><h6 class="card-title">Data Science in the Time of Covid and What Happens After</h6></a>
#       <!--Text-->
#       <p>Launch Event<br>Date: Wednesday, 24 February, 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="launch.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
#
#
#
#
#       </div>
#
#     </section>
#
#
#     <!--==========================
#       Speakers Section
#     ============================-->
# <!--     <section id="speakers" class="wow fadeInUp">
#       <div class="container">
#         <div class="section-header">
#           <br>
#           <br>
#           <h2>Our Team</h2>
#           <p>This is the team behind the seminar series</p>
#         </div>
#
#         <div class="row">
#           <div class="col-lg-4 col-md-6">
#             <div class="speaker">
#               <img src="img/speakers/1.png" alt="Speaker 1" class="img-fluid">
#               <div class="details">
#                 <h3><a href="speaker-details.html">Prof. Slava Jankin</a></h3>
#                 <p>Director of Hertie School Data Science Lab</p>
#                 <div class="social">
#                   <a href="https://twitter.com/smych?lang=en"><i class="fa fa-twitter"></i></a>
#                   <a href="https://scholar.google.com/citations?user=DUorn6wAAAAJ&hl=en"><i class="fa fa-google"></i></a>
#                   <a href="mailto:jankin@hertie-school.org"><i class="fa fa-at"></i></a>
#                   <a href="https://www.linkedin.com/in/slava-jankin/"><i class="fa fa-linkedin"></i></a>
#                 </div>
#               </div>
#             </div>
#           </div>
#           <div class="col-lg-4 col-md-6">
#             <div class="speaker">
#               <img src="img/speakers/2.jpg" alt="Speaker 2" class="img-fluid">
#               <div class="details">
#                 <h3><a href="speaker-details-2.html">Prof. Kenneth Benoit</a></h3>
#                 <p>Director of Data Science Institute, LSE</p>
#                 <div class="social">
#                   <a href="https://twitter.com/kenbenoit"><i class="fa fa-twitter"></i></a>
#                   <a href="https://scholar.google.co.uk/citations?user=hp1p9TEAAAAJ&hl=en"><i class="fa fa-google"></i></a>
#                   <a href="mailto:K.R.benoit@lse.ac.uk"><i class="fa fa-at"></i></a>
#                   <a href="https://www.linkedin.com/in/kenneth-benoit-69a68142"><i class="fa fa-linkedin"></i></a>
#                 </div>
#               </div>
#             </div>
#           </div>
#           <div class="col-lg-4 col-md-6">
#             <div class="speaker">
#               <img src="img/speakers/4.png" alt="Speaker 3" class="img-fluid">
#               <div class="details">
#                 <h3><a href="speaker-details-thompson.html">Dr. Erica Thompson</a></h3>
# ...
#           const embed_query = embeddings['queryEmbedding'].arraySync()[0];
#           const embed_responses = embeddings['responseEmbedding'].arraySync();
#
#           let scores = [];
#           // compute the dotProduct of each query and response pair.
#           for (let i = 0; i < embed_responses.length; i++) {
#             scores.push(dotProduct(embed_query, embed_responses[i]));
#             if (i == embed_responses.length-1){
#               // After finished computing the score, hide the loading dots again
#               document.getElementById("loading_dots").style.display = 'none';
#             }
#           }
#
#           var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i : iMax, 0);
#
#           console.log(scores);
#           console.log(tf.getBackend());
#
#           if (scores[max_idx] < 4) {
#             chosen_response = "Sorry, I can't respond to that query for now. Please do reach out directly through the form on this website to discuss your query with our team.";
#           } else {
#             chosen_response = input['responses'][max_idx];
#           }
#
#           // Show the output
#           answerDiv.style.display = 'inline-block';
#           answerDiv.style.color = 'white';
#
#           answerDiv.innerHTML = chosen_response;
#           output_timeout = setTimeout(function(){
#             answerDiv.innerHTML = "";
#           }, chosen_response.length*55);
#
#         };
#
#
#         // Do-It-related Model
#
#         // Given a model, a query (i.e. "What is his current job"), and
#         // an array of responses (["He is doing great.", "He is currently working at X."]),
#         // returns responses ranked by best reply.
#
#         //Who are the speakers?
#         const process_doit = async () => {
#           var doit_query = query.value.toLowerCase();
#
#           doit_query = doit_query.replace(" speakers","")
#           doit_query = doit_query.replace(" experts","")
#           doit_query = doit_query.replace(" faculty","")
#
#           const model = await modelUSE;
#           const input = {
#             queries: [doit_query],
#             responses: ["The speakers are from different institutions within the CIVICA network as well as occasional invited guests from external organisations."
#                 ]
#           };
#
#           const embeddings  = await model.embed(input);
#           const embed_query = embeddings['queryEmbedding'].arraySync()[0];
#           const embed_responses = embeddings['responseEmbedding'].arraySync();
#
#           let scores = [];
#           // compute the dotProduct of each query and response pair.
#           for (let i = 0; i < embed_responses.length; i++) {
#             scores.push(dotProduct(embed_query, embed_responses[i]));
#             if (i == embed_responses.length-1){
#               // After finished computing the score, hide the loading dots again
#               document.getElementById("loading_dots").style.display = 'none';
#             }
#           }
#
#           var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i : iMax, 0);
#
#           console.log(scores);
#           console.log(tf.getBackend());
#
#           if (scores[max_idx] < 4) {
#             chosen_response = "Sorry, I can't respond to that query for now. Please do reach out directly through the form on this website to discuss your query with our team.";
#           } else {
#             chosen_response = input['responses'][max_idx];
#           }
#
#           // Show the output
#           answerDiv.style.display = 'inline-block';
#           answerDiv.style.color = 'white';
#
#           answerDiv.innerHTML = chosen_response;
#           output_timeout = setTimeout(function(){
#             answerDiv.innerHTML = "";
#           }, chosen_response.length*55);
#
#         };
#
#         // Qlue-related Model
#
#         // Given a model, a query (i.e. "What is his current job"), and
#         // an array of responses (["He is doing great.", "He is currently working at X."]),
#         // returns responses ranked by best reply.
#
#         //What is the benefits of participating?
#         const process_qlue = async () => {
#           var qlue_query = query.value.toLowerCase();
#
#           qlue_query = qlue_query.replace(" benefits","")
#           qlue_query = qlue_query.replace(" qlie","")
#
#           const model = await modelUSE;
#           const input = {
#             queries: [qlue_query],
#             responses: ["The benefits and advantages to participate is to have your research exposed to a wider audience and get more diverse feedback, as well as to learn of new research and approaches in data science implemented by others in the field."
#                 ]
#           };
#
#           const embeddings  = await model.embed(input);
#           const embed_query = embeddings['queryEmbedding'].arraySync()[0];
#           const embed_responses = embeddings['responseEmbedding'].arraySync();
#
#           let scores = [];
#           // compute the dotProduct of each query and response pair.
#           for (let i = 0; i < embed_responses.length; i++) {
#             scores.push(dotProduct(embed_query, embed_responses[i]));
#             if (i == embed_responses.length-1){
#               // After finished computing the score, hide the loading dots again
#               document.getElementById("loading_dots").style.display = 'none';
#             }
#           }
#
#           var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i : iMax, 0);
#
#           console.log(scores);
#           console.log(tf.getBackend());
#
#           if (scores[max_idx] < 4) {
#             chosen_response = "Sorry, I can't respond to that query for now. Please do reach out directly through the form on this website to discuss your query with our team.";
#           } else {
#             chosen_response = input['responses'][max_idx];
#           }
#
#           // Show the output
#           answerDiv.style.display = 'inline-block';
#           answerDiv.style.color = 'white';
#
#           answerDiv.innerHTML = chosen_response;
#           output_timeout = setTimeout(function(){
#             answerDiv.innerHTML = "";
#           }, chosen_response.length*55);
#
#         };
#
#
#         // WB-related Model
#
#         // Given a model, a query (i.e. "What is his current job"), and
#         // an array of responses (["He is doing great.", "He is currently working at X."]),
#         // returns responses ranked by best reply.
#
#         //When is it
#         const process_wb = async () => {
#           var wb_query = query.value.toLowerCase();
#
#           wb_query = wb_query.replace(" take place","")
#           wb_query = wb_query.replace(" organised","")
#
#           const model = await modelUSE;
#           const input = {
#             queries: [wb_query],
#             responses: ["During covid times, the seminar series will take place online and is intended to be organised throughout the academic year. During normal times, the event will be organised in different insitutions within the CIVICA network."
#
#                 ]
#           };
#
#           const embeddings  = await model.embed(input);
#           const embed_query = embeddings['queryEmbedding'].arraySync()[0];
#           const embed_responses = embeddings['responseEmbedding'].arraySync();
#
#           let scores = [];
#           // compute the dotProduct of each query and response pair.
#           for (let i = 0; i < embed_responses.length; i++) {
#             scores.push(dotProduct(embed_query, embed_responses[i]));
#             if (i == embed_responses.length-1){
#               // After finished computing the score, hide the loading dots again
#               document.getElementById("loading_dots").style.display = 'none';
#             }
#           }
#
#           var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i : iMax, 0);
#
#           console.log(scores);
#           console.log(tf.getBackend());
#
#           if (scores[max_idx] < 4) {
#             chosen_response = "Sorry, I can't respond to that query for now. Please do reach out directly through the form on this website to discuss your query with our team;"
#           } else {
#             chosen_response = input['responses'][max_idx];
#           }
#
#           // Show the output
#           answerDiv.style.display = 'inline-block';
#           answerDiv.style.color = 'white';
#
#           answerDiv.innerHTML = chosen_response;
#           output_timeout = setTimeout(function(){
#             answerDiv.innerHTML = "";
#           }, chosen_response.length*55);
#
#         };
#
#
#         // Variable to check it is the first time load or not
#         i = 0;
#         i_model = 0;
#
#         window.onload = () => {
#           query = document.getElementById('myInput');
#           search = document.getElementById('myButton');
#           answerDiv  = document.getElementById("output");
#
#           console.log(query.value)
#
#           query.addEventListener('keyup', async (event) => {
#             if (event.key === 'Enter') {
#               if (query.value.toLowerCase()=="hi" || query.value.toLowerCase().includes("hello") || query.value.toLowerCase().includes("hallo") || query.value.toLowerCase().includes("how are you") || query.value.toLowerCase().includes("how's day") || query.value.toLowerCase().includes("what's up") || query.value.toLowerCase().includes("how do you do") || query.value.toLowerCase().includes("morning") || query.value.toLowerCase().includes("evening") || query.value.toLowerCase().includes("afternoon") || query.value.toLowerCase().includes("night")) {
#                 if (i == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i = i+1;
#
#                 chosen_response = "Thanks for greeting! We are doing great. Hope you have a wonderful day :)";
#
#                 // Show the output
#                 answerDiv.style.display = 'inline-block';
#                 answerDiv.style.color = 'white';
#
#                 answerDiv.innerHTML = chosen_response;
#                 output_timeout = setTimeout(function(){
#                   answerDiv.innerHTML = "";
#                 }, chosen_response.length*55);
#               } else if (query.value.toLowerCase().includes("where you work") || query.value.toLowerCase().includes("where you works") || query.value.toLowerCase().includes("where are you working")) {
#                 if (i == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i = i+1;
#
#                 chosen_response = "We are working at CIVICA institutions";
#
#                 // Show the output
#                 answerDiv.style.display = 'inline-block';
#                 answerDiv.style.color = 'white';
#
#                 answerDiv.innerHTML = chosen_response;
#                 output_timeout = setTimeout(function(){
#                   answerDiv.innerHTML = "";
#                 }, chosen_response.length*55);
#               } else if (query.value.toLowerCase().includes("meaning of life")) {
#                 if (i == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i = i+1;
#
#                 chosen_response = "It's 42. Or if you don't like it quantified, to attend the CIVICA seminar series on data science :)";
#
#                 // Show the output
#                 answerDiv.style.display = 'inline-block';
#                 answerDiv.style.color = 'white';
#
#                 answerDiv.innerHTML = chosen_response;
#                 output_timeout = setTimeout(function(){
#                   answerDiv.innerHTML = "";
#                 }, chosen_response.length*55);
#               } else if (query.value.toLowerCase().includes("first intern")) {
#                 if (i == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i = i+1;
#
#                 chosen_response = "Sorry I don't understand your query.";
#
#                 // Show the output
#                 answerDiv.style.display = 'inline-block';
#                 answerDiv.style.color = 'white';
#
#                 answerDiv.innerHTML = chosen_response;
#                 output_timeout = setTimeout(function(){
#                   answerDiv.innerHTML = "";
#                 }, chosen_response.length*55);
#               } else {
#                 console.log(i)
#                 if (i_model == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                   document.getElementById("loading_dots").style.display = 'inline-block';
#                   modelUSE = use.loadQnA();
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i_model = i_model+1;
#
#                 // Currently only supports Web version for AI personal assistant, because of the precision issue (16 vs 32 bit) using WebGL backend and CPU backend is too slow.
#                 tf.setBackend('webgl');
#                 if (query.value.toLowerCase().includes(" traveloka") || query.value.toLowerCase().includes(" tvlk") || query.value.toLowerCase().includes(" trvloka") || query.value.toLowerCase().includes(" trave")) {
#                   process_trave();
#                 } else if (query.value.toLowerCase().includes(" tokopedia") || query.value.toLowerCase().includes(" toped") || query.value.toLowerCase().includes(" tkpd") || query.value.toLowerCase().includes(" tkopedia")){
#                   process_tokped();
#                 } else if (query.value.toLowerCase().includes(" do-it") || query.value.toLowerCase().includes(" do it") || query.value.toLowerCase().includes(" doit")){
#                   process_doit();
#                 } else if (query.value.toLowerCase().includes(" qlue") || (query.value.toLowerCase().includes(" qlie"))) {
#                   process_qlue();
#                 } else if (query.value.toLowerCase().includes(" world bank") || (query.value.toLowerCase().includes(" wb"))) {
#                   process_wb();
#                 }else {
#                   process_general();
#                 }
#               }
#             }
#           });
#         };
#
#       </script>
#
# </body>
#
# </html>

# %% [markdown]
# The code chunk above makes sense here because I want to show you how to inspect objects when in **prototype mode**. However, whenever you are writing in a Jupyter Notebook to report to someone (say, when submitting your assignment), you should remove code chunks that produce a lot of unnecessary output.
#
#
# 💡 **A DETAIL THAT SEEMS INSIGNIFICANT BUT THAT IS EXTREMELY IMPORTANT**:
# - If you are on Mac or Linux, you will find that the break line character is `\n`.
# - If you are on Windows, you will find that the break line character is `\r\n`.
# - Windows uses two characters to break lines, while Mac and Linux use only one.
# - This is a common source of errors when working with with text files in two different OS. (For example: you use Mac and collaborate with someone who uses Windows.)

# %% [markdown]
# How many characters are there in the `response.text`?

# %%
len(response.text)
# Out:
# 115124

# %% [markdown]
# Not very useful to treat is as pure string, right? We need to find a better way to parse this data.

# %% [markdown]
# ## 2.3. Parsing HTML
#
# The Scrapy Selector package is a Python library for extracting data from HTML and XML documents. It uses CSS or XPath selectors for data extraction making it a powerful tool for web scraping. It is often an essential part of the Scrapy framework but can also be used independently.
#
# When you feed HTML text to the Scrapy Selector, it processes the HTML and preserves it in a particular **object**. This object allows you to access parts of the HTML using Python's common dot notation in combination with the CSS syntax. If, for instance, you want to fetch the title of the page, you might use `selector.css('title')`.

# %%
sel.css('title')
# Out:
# [<Selector xpath='descendant-or-self::title' data='<title>CIVICA Data Science Seminar</t...'>]

# %%
#Get first title
title_text = sel.css('title::text').get()
print(title_text)
# Out:
# CIVICA Data Science Seminar

# %%
# parse the HTML code using Scrapy Selector
sel = Selector(text=response.text)
print(sel)
# Out:
# <Selector xpath=None data='<html lang="en">\r\n\r\n<head>\r\n  <meta c...'>

# %% [markdown]
# 💡 Note: I was only able to call `Selector()` directly because I had already imported it at the top of the notebook. Scroll up to see it. If I hadn't, the code above would have thrown an error.

# %% [markdown]
# **Check `sel.get()` to see the full HTML document**
#
# This has the same effect as `response.text`.

# %%
print(sel.get())
# Out:
# <html lang="en">
#
# <head>
#   <meta charset="utf-8">
#   <title>CIVICA Data Science Seminar</title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#   <meta content="CIVICA Data Science Seminar" name="keywords">
#   <meta content="A series of data science workshops and seminars" name="description">
#
#   <!-- Favicons -->
#   <link href="img/c-favicon.png" rel="icon">
#   <link href="img/apple-touch-icon.png" rel="apple-touch-icon">
#
#   <!-- Google Fonts -->
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,700,700i%7CRaleway:300,400,500,700,800" rel="stylesheet">
#
#   <!-- Bootstrap CSS File -->
#   <link href="lib/bootstrap/css/bootstrap.min.css" rel="stylesheet">
#
#   <!-- Libraries CSS Files -->
#   <link href="lib/font-awesome/css/font-awesome.min.css" rel="stylesheet">
#   <link href="lib/animate/animate.min.css" rel="stylesheet">
#   <link href="lib/venobox/venobox.css" rel="stylesheet">
#   <link href="lib/owlcarousel/assets/owl.carousel.min.css" rel="stylesheet">
#
#   <!-- Main Stylesheet File -->
#   <link href="css/style.css" rel="stylesheet">
#   <link href="lib/aos/aos.css">
#
# <!--   Mailchimp service -->
#   <link href="//cdn-images.mailchimp.com/embedcode/classic-10_7.css" rel="stylesheet" type="text/css">
#
#
# </head>
#
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async src="https://www.googletagmanager.com/gtag/js?id=G-Q9R21L0VJH"></script>
#   <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'G-Q9R21L0VJH');
#   </script>
#
# <body>
#
#   <!--==========================
#     Header
#   ============================-->
#   <header id="header">
#     <div class="container">
#
#       <div id="logo" class="pull-left">
#         <!-- Uncomment below if you prefer to use a text logo -->
#         <!-- <h1><a href="#main">C<span>o</span>nf</a></h1>-->
#         <a href="#intro" class="scrollto"><img src="img/logo.png" alt="" title=""></a>
#       </div>
#
#       <nav id="nav-menu-container">
#         <ul class="nav-menu">
#           <li class="menu-active"><a href="#intro">Home</a></li>
#           <li><a href="#about">About</a></li>
# <!--           <li><a href="#speakers">Speakers</a></li>
#  -->          <li><a href="#schedule">Schedule</a></li>
#           <li><a href="#supporters">Partner Institutions</a></li>
#           <li><a href="summerschool.html">Summer School</a></li>
#           <li><a href="#gallery">Gallery</a></li>
#           <li><a href="#contact">Contact</a></li>
#         </ul>
#       </nav><!-- #nav-menu-container -->
#     </div>
#   </header><!-- #header -->
#
#   <!--==========================
#     Intro Section
#   ============================-->
#   <section id="intro">
#     <div class="intro-container wow fadeIn">
#       <h1 class="mb-4 pb-0">CIVICA<br><span>Data Science</span> Seminar Series</h1>
# <!--       <p class="mb-4 pb-0">10-12 December, Downtown Conference Center, New York</p>
#  -->
# <!--  <a href="https://www.youtube.com/watch?v=jDDaplaOz7Q" class="venobox play-btn mb-4" data-vbtype="video"
#         data-autoplay="true"></a>
#  -->
#
#
#                 <!-- Currently only supports Web version for AI personal assistant, because of the precision issue (16 vs 32 bit) using WebGL backend and CPU backend is too slow.  -->
#                 <br>
#                 <div style="width: 500px">
#                 <input autocomplete="off" type="text" placeholder="What is this seminar series?" id="myInput" class="form-control" style="background: transparent"></div>
#                 <br>
#                 <div id="first_assistant_desc" style="color: white"><i>Greetings! I am a personal AI assistant. I am built with a pre-trained Universal Sentence Encoder model from TensorFlow-js. <br>Please ask me anything about the event with a complete sentence (e.g: "What is CIVICA?") and I'll try my best to answer your queries.</i></div>
#                 <div class="lds-ellipsis" id="loading_dots"><div></div><div></div><div></div><div></div></div>
#                 <strong><div id="output"></div></strong>
#
#                 <br>
#
# <!--       <a href="#about" class="about-btn scrollto">About The Seminar Series</a>
#  -->
#          <a href="#schedule"><div class="text-center"><button type="submit" class="register-button">Register Now</button></div></a>
#
# </div>
#   </section>
#
#   <main id="main">
#
#     <!--==========================
#       About Section
#     ============================-->
#     <section id="about">
#       <div class="container">
#         <div class="row">
#           <div class="col-lg-6">
#             <h3>About The Series</h3>
#             <p>The CIVICA Data Science seminar series is the interdisciplinary forum of the CIVICA European University of Social Sciences, and alliance of eight leading higher education and research institutions. We foster a community of researchers, practitioners, and policy makers working to address complex societal challenges through the use of novel methodological and data-driven approaches, drawing from machine learning and quantitative methods from biology, sociology, political sciences, economics, and physics among others disciplines.
# <!--             <p>The Data Science Seminar series is a multi-disciplinary series focused on applications and methodologies of data science for the social, political, and economic world. Its aim is to allow researchers to share original, new work or work in progress in order to get methodological or technical comments and suggestions.
#  -->              <br>
#               <br>
#             Shared among the partner institutions of the CIVICA network, this series directly addresses the data science research stream of the CIVICA initiative.</p>
#           </div>
#           <div class="col-lg-3">
#             <h3>Where</h3>
#             <p>During COVID19 travel restrictions, the series will take place online (e.g. using MS Teams or Zoom).</p>
#           </div>
#           <div class="col-lg-3">
#             <h3>When</h3>
#             <p>The seminar series will start with regular bi-weekly slots (Wednesdays every other week at 16.00 Central European Time) across regular academic year. The number of meetings can be expanded with the increase of partner institutions.</p>
#           </div>
#         </div>
#       </div>
#     </section>
#
#
#     <!--==========================
#       Schedule Section
#     ============================-->
#     <section id="schedule" class="section-with-bg">
#       <div class="container wow fadeInUp">
#         <div class="section-header">
#           <h2>Seminar Schedule</h2>
#           <p>Here is our tentative seminar series schedule in 2021</p>
# <!--           <a href="form.html"><div class="text-center"><button type="submit" class="register-button">Register Now</button></div></a>
#  -->
#         </div>
#
#         <div class="row" data-aos="fade-up" data-aos-delay="200">
#           <div class="col-lg-12 d-flex justify-content-center">
#             <ul id="portfolio-flters">
#               <li data-filter="*" class="filter-active">All</li>
#               <li data-filter=".filter-spring">Spring 2021</li>
#               <li data-filter=".filter-fall">Fall 2021</li>
#               <li data-filter=".filter-spring2022">Spring 2022</li>
#               <li data-filter=".filter-fall2022">Fall 2022</li>
#               <li data-filter=".filter-spring2023">Spring 2023</li>
#               <li data-filter=".filter-fall2023">Fall 2023</li>
#               <li data-filter=".filter-spring2024">Spring 2024</li>
#             </ul>
#           </div>
#         </div>
#
#
#
#
#
# <div class="card-deck row" data-aos="fade-up" data-aos-delay="400">
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2024">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2024/sess1.html"><img class="card-img-top" src="spring2024/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="spring2024/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2024/sess1.html"><h6 class="card-title">Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Tiago Ventura, Georgetown University <br> Date: Wednesday, 07 February 2024</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2024/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2023/sess4.html"><img class="card-img-top" src="fall2023/visuals/sess4/sess4.png" alt="data science"></a>
#       <a href="fall2023/sess4.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2023/sess4.html"><h6 class="card-title">Promoting the systematic use of real-world data and real-world evidence for digital health technologies across Europe: A consensus framework</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Divya Srivastava, LSE <br> Date: Wednesday, 22 November 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2023/sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2023/sess3.html"><img class="card-img-top" src="fall2023/visuals/sess3/sess3.png" alt="data science"></a>
#       <a href="fall2023/sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2023/sess3.html"><h6 class="card-title">Data science for the Sustainable Development Goals: the case of food security</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Elisa Omodei, CEU <br> Date: Wednesday, 18 October 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2023/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2023/sess2.html"><img class="card-img-top" src="fall2023/visuals/sess2/sess2.png" alt="data science"></a>
#       <a href="fall2023/sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2023/sess2.html"><h6 class="card-title">CentralBankRoBERTa: A Fine-Tuned Large Language Model for Central Bank Communications</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Moritz Pfeifer &amp; Vincent Philipp Marohl <br> Date: Wednesday, 27 September 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2023/sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2023/sess1.html"><img class="card-img-top" src="fall2023/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="fall2023/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2023/sess1.html"><h6 class="card-title">The Evolution of the Climate Discourse on Twitter: Polarization, Hypocrisy, and the Musk Takeover</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Max Falkenberg <br> Date: Wednesday, 13 September 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2023/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="card-deck row" data-aos="fade-up" data-aos-delay="400">
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess7.html"><img class="card-img-top" src="spring2023/visuals/sess7/sess7.png" alt="data science"></a>
#       <a href="spring2023/sess7.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess7.html"><h6 class="card-title">The Handbook of Computational Social Science for Policy</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Eleonora Bertoni <br> Date: Wednesday, 31 May 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess7.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess6.html"><img class="card-img-top" src="spring2023/visuals/sess6/sess6.png" alt="data science"></a>
#       <a href="spring2023/sess6.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess6.html"><h6 class="card-title">Artificial Intelligence, Algorithmic Recommendations and Competition</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Giacomo Calzolari <br> Date: Wednesday, 03 May 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess6.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess5.html"><img class="card-img-top" src="spring2023/visuals/sess5/sess5.png" alt="data science"></a>
#       <a href="spring2023/sess5.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess5.html"><h6 class="card-title">Exploring A New Model of Industry/Academic Collaboration: the U.S. 2020 Facebook and Instagram Election Study</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Pablo Barberá <br> Date: Wednesday, 19 April 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess5.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess4.html"><img class="card-img-top" src="spring2023/visuals/sess4/sess4.png" alt="data science"></a>
#       <a href="spring2023/sess4.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess4.html"><h6 class="card-title">Using Multimodal Neural Networks to Better Understand How Voters Process Audiovisual Information</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Bryce Jensen Dietrich <br> Date: Wednesday, 22 March 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess3.html"><img class="card-img-top" src="spring2023/visuals/sess3/sess3.png" alt="data science"></a>
#       <a href="spring2023/sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess3.html"><h6 class="card-title">Models, mathematics, and data science: how to make sure we're answering the right questions</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Erica Thompson <br> Date: Wednesday, 08 March 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="polarisation/2023.html"><img class="card-img-top" src="polarisation/assets/img/poster.jpeg" alt="data science"></a>
#       <a href="polarisation/2023.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="polarisation/2023.html"><h6 class="card-title">CIVICA Conference on European Polarisation</h6></a>
#       <!--Text-->
#       <p class="card-text">Full day event <br> Date: Wednesday, 15 February 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="polarisation/2023.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess2.html"><img class="card-img-top" src="spring2023/visuals/sess2/sess2.png" alt="data science"></a>
#       <a href="spring2023/sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess2.html"><h6 class="card-title">New Faces of Bias in Online Platforms</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Aniko Hannak <br> Date: Wednesday, 08 February 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2023">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2023/sess1.html"><img class="card-img-top" src="spring2023/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="spring2023/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2023/sess1.html"><h6 class="card-title">Introducing the Online Harms Observatory: AI powered mapping of online abuse in real-time</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Pica Johnsson <br> Date: Wednesday, 11 January 2023</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2023/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2022/sess3.html"><img class="card-img-top" src="fall2022/visuals/sess3/sess3.png" alt="data science"></a>
#       <a href="fall2022/sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2022/sess3.html"><h6 class="card-title">Using Open Source Data Streams and Surveys to Improve Our Understanding of Elections</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Lisa Singh <br> Date: Wednesday, 02 November 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2022/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2022/sess2.html"><img class="card-img-top" src="fall2022/visuals/sess2/sess2.png" alt="data science"></a>
#       <a href="fall2022/sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2022/sess2.html"><h6 class="card-title">Does Epistemic Vice Explain Corporate Misconduct?</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Marco Meyer <br> Date: Wednesday, 19 October 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2022/sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess10.html"><img class="card-img-top" src="spring2022/visuals/sess10/sess10.png" alt="data science"></a>
#       <a href="spring2022/sess10.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess10.html"><h6 class="card-title">Becoming a data scientist: what it means to put data to work</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Anne Beaulieu <br> Date: Wednesday, 14 September 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess10.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess9.html"><img class="card-img-top" src="spring2022/visuals/sess9/sess9.png" alt="data science"></a>
#       <a href="spring2022/sess9.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess9.html"><h6 class="card-title">The Making of a French Migration Crisis</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Michelle Reddy &amp; Dr. Hélène Thiollet <br> Date: Wednesday, 15 June 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess9.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess8.html"><img class="card-img-top" src="spring2022/visuals/sess8/sess8.png" alt="data science"></a>
#       <a href="spring2022/sess8.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess8.html"><h6 class="card-title">A New Approach to Visualizing Spatial Exposure Data for Comparing Earthquakes</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Stephanie Lackner <br> Date: Wednesday, 01 June 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess8.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess7.html"><img class="card-img-top" src="spring2022/visuals/sess7/sess7.png" alt="data science"></a>
#       <a href="spring2022/sess7.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess7.html"><h6 class="card-title">Modeling Sustainable Development from the Bottom Up</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Omar A. Guerrero <br> Date: Wednesday, 04 May 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess7.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess6.html"><img class="card-img-top" src="spring2022/visuals/sess6/sess6.png" alt="data science"></a>
#       <a href="spring2022/sess6.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess6.html"><h6 class="card-title">Internet Communities and the French Presidential Election</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. David Chavalarias <br> Date: Wednesday, 20 April 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess6.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess5.html"><img class="card-img-top" src="spring2022/visuals/sess5/sess5.png" alt="data science"></a>
#       <a href="spring2022/sess5.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess5.html"><h6 class="card-title">The Science of Success: Quantifying Outcomes in Social System</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Laszlo Barabasi <br> Date: Wednesday, 09 March 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess5.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess4.html"><img class="card-img-top" src="spring2022/visuals/sess4/sess4.png" alt="data science"></a>
#       <a href="spring2022/sess4.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess4.html"><h6 class="card-title">Embedding Regression: Models for Context-Specific Description and Inference</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Arthur Spirling <br>Date: Wednesday, 23 February 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess3.html"><img class="card-img-top" src="spring2022/visuals/sess3/sess3.png" alt="data science"></a>
#       <a href="spring2022/sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess3.html"><h6 class="card-title">Information and Irregular Migration: Evidence from a Field Experiment in Nigeria</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Alexandra Scacco <br> Date: Wednesday, 09 February 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess2.html"><img class="card-img-top" src="spring2022/visuals/sess2/sess2.png" alt="data science"></a>
#       <a href="spring2022/sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess2.html"><h6 class="card-title">Adjusting for Confounding with Text Matching</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Margaret Roberts <br>Date: Wednesday, 26 January 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring2022">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2022/sess1.html"><img class="card-img-top" src="spring2022/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="spring2022/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2022/sess1.html"><h6 class="card-title">What is Data Feminist?</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Lauren Klein <br>Date: Wednesday, 12 January 2022</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2022/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2021/sess7.html"><img class="card-img-top" src="fall2021/visuals/sess7/sess7.png" alt="data science"></a>
#       <a href="fall2021/sess7.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess7.html"><h6 class="card-title">The Principles of Collective Learning</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Cesar A. Hidalgo <br> Date: Wednesday, 1 December 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess7.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2021/sess5.html"><img class="card-img-top" src="fall2021/visuals/sess5/sess5.png" alt="data science"></a>
#       <a href="fall2021/sess5.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess5.html"><h6 class="card-title">More Than Words: How Political Rhetoric Shapes Voters' Affect and Evluation</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Christopher Lucas <br> Date: Wednesday, 3 November 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess5.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2021/sess4.html"><img class="card-img-top" src="fall2021/visuals/sess4/sess4.png" alt="data science"></a>
#       <a href="fall2021/sess4.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess4.html"><h6 class="card-title">Serendipity or Confinement? Deconstructing Algorithmic Recommendation</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Camille Roth <br>Date: Wednesday, 20 October 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="bg-image hover-overlay ripple shadow-1-strong rounded" data-mdb-ripple-color="light">
#       <a href="fall2021/sess3.html">
# <img class="card-img-top" src="fall2021/visuals/sess3/sess3.png"></a>
#
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess3.html"><h6 class="card-title">Framing a Protest: Determinants and Effects of Visual Frames</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Michelle Torrest <br>Date: Wednesday, 06 October 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess9.html"><img class="card-img-top" src="seminar-sessions/sess9/sess9.png" alt="data science"></a>
#       <a href="sess9.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess9.html"><h6 class="card-title">Understanding Beautiful Places with AI</h6></a>
#       <!--Text-->
#       <p>Speaker: Prof. Suzy Moat <br>Date: Wednesday, 22 September, 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess9.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#
#   <!-- Card -->
#
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="fall2021/sess1.html"><img class="card-img-top" src="fall2021/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="fall2021/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="fall2021/sess1.html"><h6 class="card-title">Incentives and Covid-19 Vaccination Uptake</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Macartan Humphreys<br>Date: Wednesday, 08 September 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="fall2021/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="bg-image hover-overlay ripple shadow-1-strong rounded" data-mdb-ripple-color="light ">
#       <a href="sess7.html">
# <img class="card-img-top" src="img/events/sess7/sess7.png"></a>
#
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess7.html"><h6 class="card-title">The Art of Quantitative Editing</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Laura Bronner<br>Date: Wednesday, 02 June 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess7.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess6.html"><img class="card-img-top" src="img/events/sess6/sess6.png" alt="data science"></a>
#       <a href="sess6.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess6.html"><h6 class="card-title">Breaking the Social Media Prism</h6></a>
#       <!--Text-->
#       <p>Speaker: Chris Bail<br>Date: Wednesday, 19 May, 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess6.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess5.html"><img class="card-img-top" src="img/events/sess5/sess5.png" alt="data science"></a>
#       <a href="sess5.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess5.html"><h6 class="card-title">Using Public Video Cameras to Detect Racial Distancing on City Streets</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Melissa Sands <br>Date: Wednesday, 05 May 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess5.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="bg-image hover-overlay ripple shadow-1-strong rounded" data-mdb-ripple-color="light">
#       <a href="sess4.html">
#   <img class="card-img-top" src="img/events/sess4/fakenews.png"></a>
#
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess4.html"><h6 class="card-title">How to Detect Fake News Before It Is Written</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Dr. Preslav Nakov<br>Date: Wednesday, 21 April 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess4.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess3.html"><img class="card-img-top" src="img/events/sess3/negotiating.png" alt="data science"></a>
#       <a href="sess3.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess3.html"><h6 class="card-title">Negotiating with AI: Fairness in the Labor Market</h6></a>
#       <!--Text-->
#       <p>Speaker: Prof. Christo Wilson<br>Date: Wednesday, 07 April, 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess3.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="sess2.html"><img class="card-img-top" src="img/events/sess2/tracking.png" alt="data science"></a>
#       <a href="sess2.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess2.html"><h6 class="card-title">Tracking Covid-19 with the Financial Times</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: John Burn-Murdoch<br>Date: Wednesday, 24 March 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess2.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
# </div>
#
#
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="bg-image hover-overlay ripple shadow-1-strong rounded" data-mdb-ripple-color="light">
#       <a href="sess1.html">
# <img class="card-img-top" src="img/events/sess1/police.png"></a>
#
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="sess1.html"><h6 class="card-title">Police Diversity to Prevent Violence: Does It Work?</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Roman Rivera<br>Date: Wednesday, 17 March 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
# <!-- Card deck -->
#
# <div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">
#   <!-- Card -->
#   <div class="card">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="launch.html"><img class="card-img-top" src="img/events/launch.png" alt="data science"></a>
#       <a href="launch.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="launch.html"><h6 class="card-title">Data Science in the Time of Covid and What Happens After</h6></a>
#       <!--Text-->
#       <p>Launch Event<br>Date: Wednesday, 24 February, 2021</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="launch.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>
#   <!-- Card -->
# </div>
#
#
#
#
#
#
#
#       </div>
#
#
#
#
#     <!--==========================
#       Speakers Section
#     ============================-->
# <!--     <section id="speakers" class="wow fadeInUp">
#       <div class="container">
#         <div class="section-header">
#           <br>
#           <br>
#           <h2>Our Team</h2>
#           <p>This is the team behind the seminar series</p>
#         </div>
#
#         <div class="row">
#           <div class="col-lg-4 col-md-6">
#             <div class="speaker">
#               <img src="img/speakers/1.png" alt="Speaker 1" class="img-fluid">
#               <div class="details">
#                 <h3><a href="speaker-details.html">Prof. Slava Jankin</a></h3>
#                 <p>Director of Hertie School Data Science Lab</p>
#                 <div class="social">
#                   <a href="https://twitter.com/smych?lang=en"><i class="fa fa-twitter"></i></a>
#                   <a href="https://scholar.google.com/citations?user=DUorn6wAAAAJ&hl=en"><i class="fa fa-google"></i></a>
#                   <a href="mailto:jankin@hertie-school.org"><i class="fa fa-at"></i></a>
#                   <a href="https://www.linkedin.com/in/slava-jankin/"><i class="fa fa-linkedin"></i></a>
#                 </div>
#               </div>
#             </div>
#           </div>
#           <div class="col-lg-4 col-md-6">
#             <div class="speaker">
#               <img src="img/speakers/2.jpg" alt="Speaker 2" class="img-fluid">
#               <div class="details">
#                 <h3><a href="speaker-details-2.html">Prof. Kenneth Benoit</a></h3>
#                 <p>Director of Data Science Institute, LSE</p>
#                 <div class="social">
#                   <a href="https://twitter.com/kenbenoit"><i class="fa fa-twitter"></i></a>
#                   <a href="https://scholar.google.co.uk/citations?user=hp1p9TEAAAAJ&hl=en"><i class="fa fa-google"></i></a>
#                   <a href="mailto:K.R.benoit@lse.ac.uk"><i class="fa fa-at"></i></a>
#                   <a href="https://www.linkedin.com/in/kenneth-benoit-69a68142"><i class="fa fa-linkedin"></i></a>
#                 </div>
#               </div>
#             </div>
#           </div>
#           <div class="col-lg-4 col-md-6">
#             <div class="speaker">
#               <img src="img/speakers/4.png" alt="Speaker 3" class="img-fluid">
#               <div class="details">
#                 <h3><a href="speaker-details-thompson.html">Dr. Erica Thompson</a></h3>
#                 <p>Acting Director of CATS, LSE</p>
# ...
#           const embed_responses = embeddings['responseEmbedding'].arraySync();
#
#           let scores = [];
#           // compute the dotProduct of each query and response pair.
#           for (let i = 0; i < embed_responses.length; i++) {
#             scores.push(dotProduct(embed_query, embed_responses[i]));
#             if (i == embed_responses.length-1){
#               // After finished computing the score, hide the loading dots again
#               document.getElementById("loading_dots").style.display = 'none';
#             }
#           }
#
#           var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i : iMax, 0);
#
#           console.log(scores);
#           console.log(tf.getBackend());
#
#           if (scores[max_idx] < 4) {
#             chosen_response = "Sorry, I can't respond to that query for now. Please do reach out directly through the form on this website to discuss your query with our team.";
#           } else {
#             chosen_response = input['responses'][max_idx];
#           }
#
#           // Show the output
#           answerDiv.style.display = 'inline-block';
#           answerDiv.style.color = 'white';
#
#           answerDiv.innerHTML = chosen_response;
#           output_timeout = setTimeout(function(){
#             answerDiv.innerHTML = "";
#           }, chosen_response.length*55);
#
#         };
#
#
#         // Do-It-related Model
#
#         // Given a model, a query (i.e. "What is his current job"), and
#         // an array of responses (["He is doing great.", "He is currently working at X."]),
#         // returns responses ranked by best reply.
#
#         //Who are the speakers?
#         const process_doit = async () => {
#           var doit_query = query.value.toLowerCase();
#
#           doit_query = doit_query.replace(" speakers","")
#           doit_query = doit_query.replace(" experts","")
#           doit_query = doit_query.replace(" faculty","")
#
#           const model = await modelUSE;
#           const input = {
#             queries: [doit_query],
#             responses: ["The speakers are from different institutions within the CIVICA network as well as occasional invited guests from external organisations."
#                 ]
#           };
#
#           const embeddings  = await model.embed(input);
#           const embed_query = embeddings['queryEmbedding'].arraySync()[0];
#           const embed_responses = embeddings['responseEmbedding'].arraySync();
#
#           let scores = [];
#           // compute the dotProduct of each query and response pair.
#           for (let i = 0; i < embed_responses.length; i++) {
#             scores.push(dotProduct(embed_query, embed_responses[i]));
#             if (i == embed_responses.length-1){
#               // After finished computing the score, hide the loading dots again
#               document.getElementById("loading_dots").style.display = 'none';
#             }
#           }
#
#           var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i : iMax, 0);
#
#           console.log(scores);
#           console.log(tf.getBackend());
#
#           if (scores[max_idx] < 4) {
#             chosen_response = "Sorry, I can't respond to that query for now. Please do reach out directly through the form on this website to discuss your query with our team.";
#           } else {
#             chosen_response = input['responses'][max_idx];
#           }
#
#           // Show the output
#           answerDiv.style.display = 'inline-block';
#           answerDiv.style.color = 'white';
#
#           answerDiv.innerHTML = chosen_response;
#           output_timeout = setTimeout(function(){
#             answerDiv.innerHTML = "";
#           }, chosen_response.length*55);
#
#         };
#
#         // Qlue-related Model
#
#         // Given a model, a query (i.e. "What is his current job"), and
#         // an array of responses (["He is doing great.", "He is currently working at X."]),
#         // returns responses ranked by best reply.
#
#         //What is the benefits of participating?
#         const process_qlue = async () => {
#           var qlue_query = query.value.toLowerCase();
#
#           qlue_query = qlue_query.replace(" benefits","")
#           qlue_query = qlue_query.replace(" qlie","")
#
#           const model = await modelUSE;
#           const input = {
#             queries: [qlue_query],
#             responses: ["The benefits and advantages to participate is to have your research exposed to a wider audience and get more diverse feedback, as well as to learn of new research and approaches in data science implemented by others in the field."
#                 ]
#           };
#
#           const embeddings  = await model.embed(input);
#           const embed_query = embeddings['queryEmbedding'].arraySync()[0];
#           const embed_responses = embeddings['responseEmbedding'].arraySync();
#
#           let scores = [];
#           // compute the dotProduct of each query and response pair.
#           for (let i = 0; i < embed_responses.length; i++) {
#             scores.push(dotProduct(embed_query, embed_responses[i]));
#             if (i == embed_responses.length-1){
#               // After finished computing the score, hide the loading dots again
#               document.getElementById("loading_dots").style.display = 'none';
#             }
#           }
#
#           var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i : iMax, 0);
#
#           console.log(scores);
#           console.log(tf.getBackend());
#
#           if (scores[max_idx] < 4) {
#             chosen_response = "Sorry, I can't respond to that query for now. Please do reach out directly through the form on this website to discuss your query with our team.";
#           } else {
#             chosen_response = input['responses'][max_idx];
#           }
#
#           // Show the output
#           answerDiv.style.display = 'inline-block';
#           answerDiv.style.color = 'white';
#
#           answerDiv.innerHTML = chosen_response;
#           output_timeout = setTimeout(function(){
#             answerDiv.innerHTML = "";
#           }, chosen_response.length*55);
#
#         };
#
#
#         // WB-related Model
#
#         // Given a model, a query (i.e. "What is his current job"), and
#         // an array of responses (["He is doing great.", "He is currently working at X."]),
#         // returns responses ranked by best reply.
#
#         //When is it
#         const process_wb = async () => {
#           var wb_query = query.value.toLowerCase();
#
#           wb_query = wb_query.replace(" take place","")
#           wb_query = wb_query.replace(" organised","")
#
#           const model = await modelUSE;
#           const input = {
#             queries: [wb_query],
#             responses: ["During covid times, the seminar series will take place online and is intended to be organised throughout the academic year. During normal times, the event will be organised in different insitutions within the CIVICA network."
#
#                 ]
#           };
#
#           const embeddings  = await model.embed(input);
#           const embed_query = embeddings['queryEmbedding'].arraySync()[0];
#           const embed_responses = embeddings['responseEmbedding'].arraySync();
#
#           let scores = [];
#           // compute the dotProduct of each query and response pair.
#           for (let i = 0; i < embed_responses.length; i++) {
#             scores.push(dotProduct(embed_query, embed_responses[i]));
#             if (i == embed_responses.length-1){
#               // After finished computing the score, hide the loading dots again
#               document.getElementById("loading_dots").style.display = 'none';
#             }
#           }
#
#           var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i : iMax, 0);
#
#           console.log(scores);
#           console.log(tf.getBackend());
#
#           if (scores[max_idx] < 4) {
#             chosen_response = "Sorry, I can't respond to that query for now. Please do reach out directly through the form on this website to discuss your query with our team;"
#           } else {
#             chosen_response = input['responses'][max_idx];
#           }
#
#           // Show the output
#           answerDiv.style.display = 'inline-block';
#           answerDiv.style.color = 'white';
#
#           answerDiv.innerHTML = chosen_response;
#           output_timeout = setTimeout(function(){
#             answerDiv.innerHTML = "";
#           }, chosen_response.length*55);
#
#         };
#
#
#         // Variable to check it is the first time load or not
#         i = 0;
#         i_model = 0;
#
#         window.onload = () => {
#           query = document.getElementById('myInput');
#           search = document.getElementById('myButton');
#           answerDiv  = document.getElementById("output");
#
#           console.log(query.value)
#
#           query.addEventListener('keyup', async (event) => {
#             if (event.key === 'Enter') {
#               if (query.value.toLowerCase()=="hi" || query.value.toLowerCase().includes("hello") || query.value.toLowerCase().includes("hallo") || query.value.toLowerCase().includes("how are you") || query.value.toLowerCase().includes("how's day") || query.value.toLowerCase().includes("what's up") || query.value.toLowerCase().includes("how do you do") || query.value.toLowerCase().includes("morning") || query.value.toLowerCase().includes("evening") || query.value.toLowerCase().includes("afternoon") || query.value.toLowerCase().includes("night")) {
#                 if (i == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i = i+1;
#
#                 chosen_response = "Thanks for greeting! We are doing great. Hope you have a wonderful day :)";
#
#                 // Show the output
#                 answerDiv.style.display = 'inline-block';
#                 answerDiv.style.color = 'white';
#
#                 answerDiv.innerHTML = chosen_response;
#                 output_timeout = setTimeout(function(){
#                   answerDiv.innerHTML = "";
#                 }, chosen_response.length*55);
#               } else if (query.value.toLowerCase().includes("where you work") || query.value.toLowerCase().includes("where you works") || query.value.toLowerCase().includes("where are you working")) {
#                 if (i == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i = i+1;
#
#                 chosen_response = "We are working at CIVICA institutions";
#
#                 // Show the output
#                 answerDiv.style.display = 'inline-block';
#                 answerDiv.style.color = 'white';
#
#                 answerDiv.innerHTML = chosen_response;
#                 output_timeout = setTimeout(function(){
#                   answerDiv.innerHTML = "";
#                 }, chosen_response.length*55);
#               } else if (query.value.toLowerCase().includes("meaning of life")) {
#                 if (i == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i = i+1;
#
#                 chosen_response = "It's 42. Or if you don't like it quantified, to attend the CIVICA seminar series on data science :)";
#
#                 // Show the output
#                 answerDiv.style.display = 'inline-block';
#                 answerDiv.style.color = 'white';
#
#                 answerDiv.innerHTML = chosen_response;
#                 output_timeout = setTimeout(function(){
#                   answerDiv.innerHTML = "";
#                 }, chosen_response.length*55);
#               } else if (query.value.toLowerCase().includes("first intern")) {
#                 if (i == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i = i+1;
#
#                 chosen_response = "Sorry I don't understand your query.";
#
#                 // Show the output
#                 answerDiv.style.display = 'inline-block';
#                 answerDiv.style.color = 'white';
#
#                 answerDiv.innerHTML = chosen_response;
#                 output_timeout = setTimeout(function(){
#                   answerDiv.innerHTML = "";
#                 }, chosen_response.length*55);
#               } else {
#                 console.log(i)
#                 if (i_model == 0){
#                   // Hide output
#                   answerDiv.style.display = 'none';
#                   // Hide Assistant Description and show loading dots for the first query
#                   document.getElementById("first_assistant_desc").style.display = 'none';
#                   document.getElementById("loading_dots").style.display = 'inline-block';
#                   modelUSE = use.loadQnA();
#                 } else {
#                   // Hide output & clear timeout output from previous iter
#                   answerDiv.style.display = 'none';
#                   clearTimeout(output_timeout);
#                 }
#
#                 i_model = i_model+1;
#
#                 // Currently only supports Web version for AI personal assistant, because of the precision issue (16 vs 32 bit) using WebGL backend and CPU backend is too slow.
#                 tf.setBackend('webgl');
#                 if (query.value.toLowerCase().includes(" traveloka") || query.value.toLowerCase().includes(" tvlk") || query.value.toLowerCase().includes(" trvloka") || query.value.toLowerCase().includes(" trave")) {
#                   process_trave();
#                 } else if (query.value.toLowerCase().includes(" tokopedia") || query.value.toLowerCase().includes(" toped") || query.value.toLowerCase().includes(" tkpd") || query.value.toLowerCase().includes(" tkopedia")){
#                   process_tokped();
#                 } else if (query.value.toLowerCase().includes(" do-it") || query.value.toLowerCase().includes(" do it") || query.value.toLowerCase().includes(" doit")){
#                   process_doit();
#                 } else if (query.value.toLowerCase().includes(" qlue") || (query.value.toLowerCase().includes(" qlie"))) {
#                   process_qlue();
#                 } else if (query.value.toLowerCase().includes(" world bank") || (query.value.toLowerCase().includes(" wb"))) {
#                   process_wb();
#                 }else {
#                   process_general();
#                 }
#               }
#             }
#           });
#         };
#
#       </script>
#
# </div></form></div></section></div></div></section></main></body>
#
# </html>

# %% [markdown]
# **HTML documents usually have a \<header\> tag:**
#
# (⚠️ not to be confused with the HTTP header we saw with `response.headers`)

# %%
sel.css('header')
# Out:
# [<Selector xpath='descendant-or-self::header' data='<header id="header">\r\n    <div class=...'>]

# %%
sel.css('div')
# Out:
# [<Selector xpath='descendant-or-self::div' data='<div class="container">\r\n\r\n      <div...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="logo" class="pull-left">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="intro-container wow fadeI...'>,
#  <Selector xpath='descendant-or-self::div' data='<div style="width: 500px">\r\n         ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="first_assistant_desc" style=...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="lds-ellipsis" id="loading...'>,
#  <Selector xpath='descendant-or-self::div' data='<div></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="output"></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="text-center"><button type...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container">\r\n        <div...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row">\r\n          <div cla...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6">\r\n            <...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3">\r\n            <...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3">\r\n            <...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container wow fadeInUp">\r...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="section-header">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row" data-aos="fade-up" d...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-12 d-flex justify-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-deck row" data-aos="...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-deck row" data-aos="...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="bg-image hover-overlay ri...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card">\r\n\r\n    <!--Card im...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="bg-image hover-overlay ri...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card">\r\n\r\n    <!--Card im...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="bg-image hover-overlay ri...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card">\r\n\r\n    <!--Card im...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card mb-4">\r\n\r\n    <!--Ca...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="bg-image hover-overlay ri...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-xs-12 col-sm-6 col-md...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card">\r\n\r\n    <!--Card im...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="view overlay">\r\n      <a ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="mask rgba-white-slight"><...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="card-body">\r\n\r\n      <!--...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container">\r\n        <div...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="section-header">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters supporters...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-2 col-md-4 col-xs-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="supporter-logo">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-2 col-md-4 col-xs-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="supporter-logo">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-2 col-md-4 col-xs-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="supporter-logo">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-2 col-md-4 col-xs-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="supporter-logo-bocconi">\r...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-2 col-md-4 col-xs-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="supporter-logo">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-2 col-md-4 col-xs-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="supporter-logo">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid">\r\n\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-map">\r\n   ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-info">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row justify-content-cente...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-11 col-lg-8">\r\n      ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid venue-gal...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n\r\n     ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid">\r\n\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n      \r...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-info">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row justify-content-cente...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-11 col-lg-8">\r\n      ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-map">\r\n   ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid venue-gal...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n\r\n     ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid">\r\n\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-map">\r\n   ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-info">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row justify-content-cente...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-11 col-lg-8">\r\n      ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid venue-gal...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n\r\n     ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid">\r\n\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n      \r...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-info">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row justify-content-cente...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-11 col-lg-8">\r\n      ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-map">\r\n   ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid venue-gal...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n\r\n     ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid">\r\n\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n      \r...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-map">\r\n   ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-info">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row justify-content-cente...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-11 col-lg-8">\r\n      ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid venue-gal...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n\r\n     ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid">\r\n\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n      \r...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-info">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row justify-content-cente...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-11 col-lg-8">\r\n      ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-6 venue-map">\r\n   ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container-fluid venue-gal...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row no-gutters">\r\n\r\n     ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-4">\r\n    ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="venue-gallery">\r\n        ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container">\r\n        <div...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="section-header">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="owl-carousel gallery-caro...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container">\r\n\r\n        <d...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="section-header">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row justify-content-cente...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-9">\r\n             ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="faq1" class="collapse" data-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="faq2" class="collapse" data-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="faq3" class="collapse" data-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="faq4" class="collapse" data-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="faq5" class="collapse" data-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="faq6" class="collapse" data-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container wow fadeInUp">\r...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="section-header">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="form-row justify-content-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-auto">\r\n             ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-auto">\r\n             ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container">\r\n\r\n        <d...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="section-header">\r\n       ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="form">\r\n          <div id...'>,
#  <Selector xpath='descendant-or-self::div' data='<div id="sendmessage">Your message ha...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="form-row">\r\n             ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="form-group col-md-6">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="validation"></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="form-group col-md-6">\r\n  ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="validation"></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="form-group">\r\n           ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="validation"></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="form-group">\r\n           ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="validation"></div>'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="text-center"><button type...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="footer-top">\r\n      <div ...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container">\r\n        <div...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="row">\r\n\r\n          <div c...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-6 footer-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-6 footer-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-6 footer-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="col-lg-3 col-md-6 footer-...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="container">\r\n      <div c...'>,
#  <Selector xpath='descendant-or-self::div' data='<div class="copyright">\r\n        © Co...'>]

# %% [markdown]
# There is also usually a `<body>` tag, which contains the main content of the page:

# %%
sel.css('body')
# Out:
# [<Selector xpath='descendant-or-self::body' data='<body>\r\n\r\n  <!--=====================...'>]

# %% [markdown]
# The `.card` represents that the type of division to scrape should be a `card`.

# %%
cards = sel.css('div.card')
len(cards)
# Out:
# 39

# %%
print(cards[0].extract())
# Out:
# <div class="card mb-4">
#
#     <!--Card image-->
#     <div class="view overlay">
#       <a href="spring2024/sess1.html"><img class="card-img-top" src="spring2024/visuals/sess1/sess1.png" alt="data science"></a>
#       <a href="spring2024/sess1.html">
#         <div class="mask rgba-white-slight"></div>
#       </a>
#     </div>
#
#     <!--Card content-->
#     <div class="card-body">
#
#       <!--Title-->
#       <a href="spring2024/sess1.html"><h6 class="card-title">Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil</h6></a>
#       <!--Text-->
#       <p class="card-text">Speaker: Prof. Tiago Ventura, Georgetown University <br> Date: Wednesday, 07 February 2024</p>
#       <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->
#       <a href="spring2024/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>
#
#     </div>
#
#   </div>

# %%
#This is a container:
cards[0].extract()
# Out:
# '<div class="card mb-4">\r\n\r\n    <!--Card image-->\r\n    <div class="view overlay">\r\n      <a href="spring2024/sess1.html"><img class="card-img-top" src="spring2024/visuals/sess1/sess1.png" alt="data science"></a>\r\n      <a href="spring2024/sess1.html">\r\n        <div class="mask rgba-white-slight"></div>\r\n      </a>\r\n    </div>\r\n\r\n    <!--Card content-->\r\n    <div class="card-body">\r\n\r\n      <!--Title-->\r\n      <a href="spring2024/sess1.html"><h6 class="card-title">Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil</h6></a>\r\n      <!--Text-->\r\n      <p class="card-text">Speaker: Prof. Tiago Ventura, Georgetown University <br> Date: Wednesday, 07 February 2024</p>\r\n      <!-- Provides extra visual weight and identifies the primary action in a set of buttons -->\r\n      <a href="spring2024/sess1.html"><button type="button" class="btn btn-light-blue btn-md">Read more</button></a>\r\n\r\n    </div>\r\n\r\n  </div>'

# %%
#This is a container: The below returns a list. h6 is a header
cards[0].css("h6").extract()
# Out:
# ['<h6 class="card-title">Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil</h6>']

# %%
#This is a container: The below extracts the text of the headline of the first card. h6 is a header
cards[0].css("h6 ::text").extract()
# Out:
# ['Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil']

# %%
def get_title(card):
    return card.css("h6 ::text").extract_first()

# %%
all_titles = []
for i in range(len(cards)):
    all_titles.append(get_title(cards[i]))

all_titles
# Out:
# ['Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil',
#  'Promoting the systematic use of real-world data and real-world evidence for digital health technologies across Europe: A consensus framework',
#  'Data science for the Sustainable Development Goals: the case of food security',
#  'CentralBankRoBERTa: A Fine-Tuned Large Language Model for Central Bank Communications',
#  'The Evolution of the Climate Discourse on Twitter: Polarization, Hypocrisy, and the Musk Takeover',
#  'The Handbook of Computational Social Science for Policy',
#  'Artificial Intelligence, Algorithmic Recommendations and Competition',
#  'Exploring A New Model of Industry/Academic Collaboration: the U.S. 2020 Facebook and Instagram Election Study',
#  'Using Multimodal Neural Networks to Better Understand How Voters Process Audiovisual Information',
#  "Models, mathematics, and data science: how to make sure we're answering the right questions",
#  'CIVICA Conference on European Polarisation',
#  'New Faces of Bias in Online Platforms',
#  'Introducing the Online Harms Observatory: AI powered mapping of online abuse in real-time',
#  'Using Open Source Data Streams and Surveys to Improve Our Understanding of Elections',
#  'Does Epistemic Vice Explain Corporate Misconduct?',
#  'Becoming a data scientist: what it means to put data to work',
#  'The Making of a French Migration Crisis',
#  'A New Approach to Visualizing Spatial Exposure Data for Comparing Earthquakes',
#  'Modeling Sustainable Development from the Bottom Up',
#  'Internet Communities and the French Presidential Election',
#  'The Science of Success: Quantifying Outcomes in Social System',
#  'Embedding Regression: Models for Context-Specific Description and Inference',
#  'Information and Irregular Migration: Evidence from a Field Experiment in Nigeria',
#  'Adjusting for Confounding with Text Matching',
#  'What is Data Feminist?',
#  'The Principles of Collective Learning',
#  "More Than Words: How Political Rhetoric Shapes Voters' Affect and Evluation",
#  'Serendipity or Confinement? Deconstructing Algorithmic Recommendation',
#  'Framing a Protest: Determinants and Effects of Visual Frames',
#  'Understanding Beautiful Places with AI',
#  'Incentives and Covid-19 Vaccination Uptake',
#  'The Art of Quantitative Editing',
#  'Breaking the Social Media Prism',
#  'Using Public Video Cameras to Detect Racial Distancing on City Streets',
#  'How to Detect Fake News Before It Is Written',
#  'Negotiating with AI: Fairness in the Labor Market',
#  'Tracking Covid-19 with the Financial Times',
#  'Police Diversity to Prevent Violence: Does It Work?',
#  'Data Science in the Time of Covid and What Happens After']

# %%
all_titles = [get_title(card) for card in cards]
all_titles
# Out:
# ['Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil',
#  'Promoting the systematic use of real-world data and real-world evidence for digital health technologies across Europe: A consensus framework',
#  'Data science for the Sustainable Development Goals: the case of food security',
#  'CentralBankRoBERTa: A Fine-Tuned Large Language Model for Central Bank Communications',
#  'The Evolution of the Climate Discourse on Twitter: Polarization, Hypocrisy, and the Musk Takeover',
#  'The Handbook of Computational Social Science for Policy',
#  'Artificial Intelligence, Algorithmic Recommendations and Competition',
#  'Exploring A New Model of Industry/Academic Collaboration: the U.S. 2020 Facebook and Instagram Election Study',
#  'Using Multimodal Neural Networks to Better Understand How Voters Process Audiovisual Information',
#  "Models, mathematics, and data science: how to make sure we're answering the right questions",
#  'CIVICA Conference on European Polarisation',
#  'New Faces of Bias in Online Platforms',
#  'Introducing the Online Harms Observatory: AI powered mapping of online abuse in real-time',
#  'Using Open Source Data Streams and Surveys to Improve Our Understanding of Elections',
#  'Does Epistemic Vice Explain Corporate Misconduct?',
#  'Becoming a data scientist: what it means to put data to work',
#  'The Making of a French Migration Crisis',
#  'A New Approach to Visualizing Spatial Exposure Data for Comparing Earthquakes',
#  'Modeling Sustainable Development from the Bottom Up',
#  'Internet Communities and the French Presidential Election',
#  'The Science of Success: Quantifying Outcomes in Social System',
#  'Embedding Regression: Models for Context-Specific Description and Inference',
#  'Information and Irregular Migration: Evidence from a Field Experiment in Nigeria',
#  'Adjusting for Confounding with Text Matching',
#  'What is Data Feminist?',
#  'The Principles of Collective Learning',
#  "More Than Words: How Political Rhetoric Shapes Voters' Affect and Evluation",
#  'Serendipity or Confinement? Deconstructing Algorithmic Recommendation',
#  'Framing a Protest: Determinants and Effects of Visual Frames',
#  'Understanding Beautiful Places with AI',
#  'Incentives and Covid-19 Vaccination Uptake',
#  'The Art of Quantitative Editing',
#  'Breaking the Social Media Prism',
#  'Using Public Video Cameras to Detect Racial Distancing on City Streets',
#  'How to Detect Fake News Before It Is Written',
#  'Negotiating with AI: Fairness in the Labor Market',
#  'Tracking Covid-19 with the Financial Times',
#  'Police Diversity to Prevent Violence: Does It Work?',
#  'Data Science in the Time of Covid and What Happens After']

# %%
#This is a container: The below returns a list. a is a type that represents links
cards[1].css("a").extract()[0]
# Out:
# '<a href="spring2024/sess1.html"><img class="card-img-top" src="spring2024/visuals/sess1/sess1.png" alt="data science"></a>'

# %%
#This is a container: The below returns a list. a is a type that represents links
cards[1].css("a ::text").extract()[0]
# Out:
# '\r\n        '

# %% [markdown]
# 🔑 **Takeaway of the output above:**
#
# - The output is a list, as indicated by the square brackets.
# - HTML pages only have one `<body>` tag, so this list contains a single element, which is an object of the class Selector.

# %% [markdown]
# What if I want to look at the content of the `<body>` tag?

# %%
pprint(sel.css('body').get())
# Out:
# ('<body>\r\n'
#  '\r\n'
#  '  <!--==========================\r\n'
#  '    Header\r\n'
#  '  ============================-->\r\n'
#  '  <header id="header">\r\n'
#  '    <div class="container">\r\n'
#  '\r\n'
#  '      <div id="logo" class="pull-left">\r\n'
#  '        <!-- Uncomment below if you prefer to use a text logo -->\r\n'
#  '        <!-- <h1><a href="#main">C<span>o</span>nf</a></h1>-->\r\n'
#  '        <a href="#intro" class="scrollto"><img src="img/logo.png" alt="" '
#  'title=""></a>\r\n'
#  '      </div>\r\n'
#  '\r\n'
#  '      <nav id="nav-menu-container">\r\n'
#  '        <ul class="nav-menu">\r\n'
#  '          <li class="menu-active"><a href="#intro">Home</a></li>\r\n'
#  '          <li><a href="#about">About</a></li>\r\n'
#  '<!--           <li><a href="#speakers">Speakers</a></li>\r\n'
#  ' -->          <li><a href="#schedule">Schedule</a></li>\r\n'
#  '          <li><a href="#supporters">Partner Institutions</a></li>\r\n'
#  '          <li><a href="summerschool.html">Summer School</a></li>\r\n'
#  '          <li><a href="#gallery">Gallery</a></li>\r\n'
#  '          <li><a href="#contact">Contact</a></li>\r\n'
#  '        </ul>\r\n'
#  '      </nav><!-- #nav-menu-container -->\r\n'
#  '    </div>\r\n'
#  '  </header><!-- #header -->\r\n'
#  '\r\n'
#  '  <!--==========================\r\n'
#  '    Intro Section\r\n'
#  '  ============================-->\r\n'
#  '  <section id="intro">\r\n'
#  '    <div class="intro-container wow fadeIn">\r\n'
#  '      <h1 class="mb-4 pb-0">CIVICA<br><span>Data Science</span> Seminar '
#  'Series</h1>\r\n'
#  '<!--       <p class="mb-4 pb-0">10-12 December, Downtown Conference Center, '
#  'New York</p>\r\n'
#  ' -->      \r\n'
#  '<!--  <a href="https://www.youtube.com/watch?v=jDDaplaOz7Q" class="venobox '
#  'play-btn mb-4" data-vbtype="video"\r\n'
#  '        data-autoplay="true"></a>\r\n'
#  ' -->\r\n'
#  '\r\n'
#  '\r\n'
#  '                <!-- Currently only supports Web version for AI personal '
#  'assistant, because of the precision issue (16 vs 32 bit) using WebGL backend '
#  'and CPU backend is too slow.  -->\r\n'
#  '                <br>\r\n'
#  '                <div style="width: 500px">\r\n'
#  '                <input autocomplete="off" type="text" placeholder="What is '
#  'this seminar series?" id="myInput" class="form-control" style="background: '
#  'transparent"></div>\r\n'
#  '                <br>\r\n'
#  '                <div id="first_assistant_desc" style="color: '
#  'white"><i>Greetings! I am a personal AI assistant. I am built with a '
#  'pre-trained Universal Sentence Encoder model from TensorFlow-js. <br>Please '
#  'ask me anything about the event with a complete sentence (e.g: "What is '
#  'CIVICA?") and I\'ll try my best to answer your queries.</i></div>\r\n'
#  '                <div class="lds-ellipsis" '
#  'id="loading_dots"><div></div><div></div><div></div><div></div></div>\r\n'
#  '                <strong><div id="output"></div></strong>\r\n'
#  '\r\n'
#  '                <br>\r\n'
#  '\r\n'
#  '<!--       <a href="#about" class="about-btn scrollto">About The Seminar '
#  'Series</a>\r\n'
#  ' -->    \r\n'
#  '         <a href="#schedule"><div class="text-center"><button type="submit" '
#  'class="register-button">Register Now</button></div></a>\r\n'
#  '\r\n'
#  '</div>\r\n'
#  '  </section>\r\n'
#  '\r\n'
#  '  <main id="main">\r\n'
#  '\r\n'
#  '    <!--==========================\r\n'
#  '      About Section\r\n'
#  '    ============================-->\r\n'
#  '    <section id="about">\r\n'
#  '      <div class="container">\r\n'
#  '        <div class="row">\r\n'
#  '          <div class="col-lg-6">\r\n'
#  '            <h3>About The Series</h3>\r\n'
#  '            <p>The CIVICA Data Science seminar series is the '
#  'interdisciplinary forum of the CIVICA European University of Social '
#  'Sciences, and alliance of eight leading higher education and research '
#  'institutions. We foster a community of researchers, practitioners, and '
#  'policy makers working to address complex societal challenges through the use '
#  'of novel methodological and data-driven approaches, drawing from machine '
#  'learning and quantitative methods from biology, sociology, political '
#  'sciences, economics, and physics among others disciplines.\r\n'
#  '<!--             <p>The Data Science Seminar series is a multi-disciplinary '
#  'series focused on applications and methodologies of data science for the '
#  'social, political, and economic world. Its aim is to allow researchers to '
#  'share original, new work or work in progress in order to get methodological '
#  'or technical comments and suggestions.\r\n'
#  ' -->              <br>\r\n'
#  '              <br>\r\n'
#  '            Shared among the partner institutions of the CIVICA network, '
#  'this series directly addresses the data science research stream of the '
#  'CIVICA initiative.</p>\r\n'
#  '          </div>\r\n'
#  '          <div class="col-lg-3">\r\n'
#  '            <h3>Where</h3>\r\n'
#  '            <p>During COVID19 travel restrictions, the series will take '
#  'place online (e.g. using MS Teams or Zoom).</p>\r\n'
#  '          </div>\r\n'
#  '          <div class="col-lg-3">\r\n'
#  '            <h3>When</h3>\r\n'
#  '            <p>The seminar series will start with regular bi-weekly slots '
#  '(Wednesdays every other week at 16.00 Central European Time) across regular '
#  'academic year. The number of meetings can be expanded with the increase of '
#  'partner institutions.</p>\r\n'
#  '          </div>\r\n'
#  '        </div>\r\n'
#  '      </div>\r\n'
#  '    </section>\r\n'
#  '\r\n'
#  '\r\n'
#  '    <!--==========================\r\n'
#  '      Schedule Section\r\n'
#  '    ============================-->\r\n'
#  '    <section id="schedule" class="section-with-bg">\r\n'
#  '      <div class="container wow fadeInUp">\r\n'
#  '        <div class="section-header">\r\n'
#  '          <h2>Seminar Schedule</h2>\r\n'
#  '          <p>Here is our tentative seminar series schedule in 2021</p>\r\n'
#  '<!--           <a href="form.html"><div class="text-center"><button '
#  'type="submit" class="register-button">Register Now</button></div></a>\r\n'
#  ' -->\r\n'
#  '        </div>\r\n'
#  '\r\n'
#  '        <div class="row" data-aos="fade-up" data-aos-delay="200">\r\n'
#  '          <div class="col-lg-12 d-flex justify-content-center">\r\n'
#  '            <ul id="portfolio-flters">\r\n'
#  '              <li data-filter="*" class="filter-active">All</li>\r\n'
#  '              <li data-filter=".filter-spring">Spring 2021</li>\r\n'
#  '              <li data-filter=".filter-fall">Fall 2021</li>\r\n'
#  '              <li data-filter=".filter-spring2022">Spring 2022</li>\r\n'
#  '              <li data-filter=".filter-fall2022">Fall 2022</li>\r\n'
#  '              <li data-filter=".filter-spring2023">Spring 2023</li>\r\n'
#  '              <li data-filter=".filter-fall2023">Fall 2023</li>\r\n'
#  '              <li data-filter=".filter-spring2024">Spring 2024</li>\r\n'
#  '            </ul>\r\n'
#  '          </div>\r\n'
#  '        </div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="card-deck row" data-aos="fade-up" data-aos-delay="400">\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2024">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2024/sess1.html"><img class="card-img-top" '
#  'src="spring2024/visuals/sess1/sess1.png" alt="data science"></a>\r\n'
#  '      <a href="spring2024/sess1.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2024/sess1.html"><h6 class="card-title">Misinformation '
#  'exposure beyond traditional feeds: Evidence from a WhatsApp deactivation '
#  'experiment in Brazil</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Tiago Ventura, Georgetown '
#  'University <br> Date: Wednesday, 07 February 2024</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2024/sess1.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2023/sess4.html"><img class="card-img-top" '
#  'src="fall2023/visuals/sess4/sess4.png" alt="data science"></a>\r\n'
#  '      <a href="fall2023/sess4.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2023/sess4.html"><h6 class="card-title">Promoting the '
#  'systematic use of real-world data and real-world evidence for digital health '
#  'technologies across Europe: A consensus framework</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Divya Srivastava, LSE <br> Date: '
#  'Wednesday, 22 November 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2023/sess4.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2023/sess3.html"><img class="card-img-top" '
#  'src="fall2023/visuals/sess3/sess3.png" alt="data science"></a>\r\n'
#  '      <a href="fall2023/sess3.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2023/sess3.html"><h6 class="card-title">Data science for '
#  'the Sustainable Development Goals: the case of food security</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Elisa Omodei, CEU <br> Date: '
#  'Wednesday, 18 October 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2023/sess3.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2023/sess2.html"><img class="card-img-top" '
#  'src="fall2023/visuals/sess2/sess2.png" alt="data science"></a>\r\n'
#  '      <a href="fall2023/sess2.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2023/sess2.html"><h6 '
#  'class="card-title">CentralBankRoBERTa: A Fine-Tuned Large Language Model for '
#  'Central Bank Communications</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Moritz Pfeifer &amp; Vincent Philipp '
#  'Marohl <br> Date: Wednesday, 27 September 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2023/sess2.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2023/sess1.html"><img class="card-img-top" '
#  'src="fall2023/visuals/sess1/sess1.png" alt="data science"></a>\r\n'
#  '      <a href="fall2023/sess1.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2023/sess1.html"><h6 class="card-title">The Evolution of '
#  'the Climate Discourse on Twitter: Polarization, Hypocrisy, and the Musk '
#  'Takeover</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Max Falkenberg <br> Date: Wednesday, '
#  '13 September 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2023/sess1.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="card-deck row" data-aos="fade-up" data-aos-delay="400">\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2023/sess7.html"><img class="card-img-top" '
#  'src="spring2023/visuals/sess7/sess7.png" alt="data science"></a>\r\n'
#  '      <a href="spring2023/sess7.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2023/sess7.html"><h6 class="card-title">The Handbook of '
#  'Computational Social Science for Policy</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Eleonora Bertoni <br> Date: '
#  'Wednesday, 31 May 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2023/sess7.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2023/sess6.html"><img class="card-img-top" '
#  'src="spring2023/visuals/sess6/sess6.png" alt="data science"></a>\r\n'
#  '      <a href="spring2023/sess6.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2023/sess6.html"><h6 class="card-title">Artificial '
#  'Intelligence, Algorithmic Recommendations and Competition</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Giacomo Calzolari <br> Date: '
#  'Wednesday, 03 May 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2023/sess6.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2023/sess5.html"><img class="card-img-top" '
#  'src="spring2023/visuals/sess5/sess5.png" alt="data science"></a>\r\n'
#  '      <a href="spring2023/sess5.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2023/sess5.html"><h6 class="card-title">Exploring A New '
#  'Model of Industry/Academic Collaboration: the U.S. 2020 Facebook and '
#  'Instagram Election Study</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Pablo Barberá <br> Date: '
#  'Wednesday, 19 April 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2023/sess5.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2023/sess4.html"><img class="card-img-top" '
#  'src="spring2023/visuals/sess4/sess4.png" alt="data science"></a>\r\n'
#  '      <a href="spring2023/sess4.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2023/sess4.html"><h6 class="card-title">Using '
#  'Multimodal Neural Networks to Better Understand How Voters Process '
#  'Audiovisual Information</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Bryce Jensen Dietrich <br> Date: '
#  'Wednesday, 22 March 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2023/sess4.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2023/sess3.html"><img class="card-img-top" '
#  'src="spring2023/visuals/sess3/sess3.png" alt="data science"></a>\r\n'
#  '      <a href="spring2023/sess3.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2023/sess3.html"><h6 class="card-title">Models, '
#  "mathematics, and data science: how to make sure we're answering the right "
#  'questions</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Erica Thompson <br> Date: Wednesday, '
#  '08 March 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2023/sess3.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="polarisation/2023.html"><img class="card-img-top" '
#  'src="polarisation/assets/img/poster.jpeg" alt="data science"></a>\r\n'
#  '      <a href="polarisation/2023.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="polarisation/2023.html"><h6 class="card-title">CIVICA '
#  'Conference on European Polarisation</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Full day event <br> Date: Wednesday, 15 February '
#  '2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="polarisation/2023.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '                                                                                                                                                                                                                                                                              \r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2023/sess2.html"><img class="card-img-top" '
#  'src="spring2023/visuals/sess2/sess2.png" alt="data science"></a>\r\n'
#  '      <a href="spring2023/sess2.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2023/sess2.html"><h6 class="card-title">New Faces of '
#  'Bias in Online Platforms</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Aniko Hannak <br> Date: Wednesday, '
#  '08 February 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2023/sess2.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2023">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2023/sess1.html"><img class="card-img-top" '
#  'src="spring2023/visuals/sess1/sess1.png" alt="data science"></a>\r\n'
#  '      <a href="spring2023/sess1.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2023/sess1.html"><h6 class="card-title">Introducing the '
#  'Online Harms Observatory: AI powered mapping of online abuse in '
#  'real-time</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Pica Johnsson <br> Date: Wednesday, 11 '
#  'January 2023</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2023/sess1.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2022/sess3.html"><img class="card-img-top" '
#  'src="fall2022/visuals/sess3/sess3.png" alt="data science"></a>\r\n'
#  '      <a href="fall2022/sess3.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2022/sess3.html"><h6 class="card-title">Using Open Source '
#  'Data Streams and Surveys to Improve Our Understanding of '
#  'Elections</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Lisa Singh <br> Date: Wednesday, '
#  '02 November 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2022/sess3.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2022/sess2.html"><img class="card-img-top" '
#  'src="fall2022/visuals/sess2/sess2.png" alt="data science"></a>\r\n'
#  '      <a href="fall2022/sess2.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2022/sess2.html"><h6 class="card-title">Does Epistemic '
#  'Vice Explain Corporate Misconduct?</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Marco Meyer <br> Date: Wednesday, 19 '
#  'October 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2022/sess2.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess10.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess10/sess10.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess10.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess10.html"><h6 class="card-title">Becoming a '
#  'data scientist: what it means to put data to work</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Anne Beaulieu <br> Date: '
#  'Wednesday, 14 September 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess10.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess9.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess9/sess9.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess9.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess9.html"><h6 class="card-title">The Making of a '
#  'French Migration Crisis</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Michelle Reddy &amp; Dr. Hélène '
#  'Thiollet <br> Date: Wednesday, 15 June 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess9.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess8.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess8/sess8.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess8.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess8.html"><h6 class="card-title">A New Approach '
#  'to Visualizing Spatial Exposure Data for Comparing Earthquakes</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Stephanie Lackner <br> Date: '
#  'Wednesday, 01 June 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess8.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess7.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess7/sess7.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess7.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess7.html"><h6 class="card-title">Modeling '
#  'Sustainable Development from the Bottom Up</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Omar A. Guerrero <br> Date: '
#  'Wednesday, 04 May 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess7.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess6.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess6/sess6.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess6.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess6.html"><h6 class="card-title">Internet '
#  'Communities and the French Presidential Election</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. David Chavalarias <br> Date: '
#  'Wednesday, 20 April 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess6.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess5.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess5/sess5.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess5.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess5.html"><h6 class="card-title">The Science of '
#  'Success: Quantifying Outcomes in Social System</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Laszlo Barabasi <br> Date: '
#  'Wednesday, 09 March 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess5.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess4.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess4/sess4.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess4.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess4.html"><h6 class="card-title">Embedding '
#  'Regression: Models for Context-Specific Description and '
#  'Inference</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Arthur Spirling <br>Date: '
#  'Wednesday, 23 February 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess4.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess3.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess3/sess3.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess3.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess3.html"><h6 class="card-title">Information and '
#  'Irregular Migration: Evidence from a Field Experiment in Nigeria</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Alexandra Scacco <br> Date: '
#  'Wednesday, 09 February 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess3.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess2.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess2/sess2.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess2.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess2.html"><h6 class="card-title">Adjusting for '
#  'Confounding with Text Matching</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Margaret Roberts <br>Date: '
#  'Wednesday, 26 January 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess2.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item '
#  'filter-spring2022">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="spring2022/sess1.html"><img class="card-img-top" '
#  'src="spring2022/visuals/sess1/sess1.png" alt="data science"></a>\r\n'
#  '      <a href="spring2022/sess1.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="spring2022/sess1.html"><h6 class="card-title">What is Data '
#  'Feminist?</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Lauren Klein <br>Date: Wednesday, '
#  '12 January 2022</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="spring2022/sess1.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2021/sess7.html"><img class="card-img-top" '
#  'src="fall2021/visuals/sess7/sess7.png" alt="data science"></a>\r\n'
#  '      <a href="fall2021/sess7.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2021/sess7.html"><h6 class="card-title">The Principles of '
#  'Collective Learning</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Cesar A. Hidalgo <br> Date: '
#  'Wednesday, 1 December 2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2021/sess7.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2021/sess5.html"><img class="card-img-top" '
#  'src="fall2021/visuals/sess5/sess5.png" alt="data science"></a>\r\n'
#  '      <a href="fall2021/sess5.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2021/sess5.html"><h6 class="card-title">More Than Words: '
#  "How Political Rhetoric Shapes Voters' Affect and Evluation</h6></a>\r\n"
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Christopher Lucas <br> Date: '
#  'Wednesday, 3 November 2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2021/sess5.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2021/sess4.html"><img class="card-img-top" '
#  'src="fall2021/visuals/sess4/sess4.png" alt="data science"></a>\r\n'
#  '      <a href="fall2021/sess4.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2021/sess4.html"><h6 class="card-title">Serendipity or '
#  'Confinement? Deconstructing Algorithmic Recommendation</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Camille Roth <br>Date: Wednesday, '
#  '20 October 2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2021/sess4.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="bg-image hover-overlay ripple shadow-1-strong rounded" '
#  'data-mdb-ripple-color="light">\r\n'
#  '      <a href="fall2021/sess3.html">\r\n'
#  '<img class="card-img-top" src="fall2021/visuals/sess3/sess3.png"></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2021/sess3.html"><h6 class="card-title">Framing a '
#  'Protest: Determinants and Effects of Visual Frames</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Michelle Torrest <br>Date: '
#  'Wednesday, 06 October 2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2021/sess3.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '  <!-- Card -->\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="sess9.html"><img class="card-img-top" '
#  'src="seminar-sessions/sess9/sess9.png" alt="data science"></a>\r\n'
#  '      <a href="sess9.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="sess9.html"><h6 class="card-title">Understanding Beautiful '
#  'Places with AI</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p>Speaker: Prof. Suzy Moat <br>Date: Wednesday, 22 September, '
#  '2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="sess9.html"><button type="button" class="btn btn-light-blue '
#  'btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '  \r\n'
#  '  <!-- Card -->\r\n'
#  '\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-fall">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="fall2021/sess1.html"><img class="card-img-top" '
#  'src="fall2021/visuals/sess1/sess1.png" alt="data science"></a>\r\n'
#  '      <a href="fall2021/sess1.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="fall2021/sess1.html"><h6 class="card-title">Incentives and '
#  'Covid-19 Vaccination Uptake</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Prof. Macartan Humphreys<br>Date: '
#  'Wednesday, 08 September 2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="fall2021/sess1.html"><button type="button" class="btn '
#  'btn-light-blue btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="bg-image hover-overlay ripple shadow-1-strong rounded" '
#  'data-mdb-ripple-color="light ">\r\n'
#  '      <a href="sess7.html">\r\n'
#  '<img class="card-img-top" src="img/events/sess7/sess7.png"></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="sess7.html"><h6 class="card-title">The Art of Quantitative '
#  'Editing</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Laura Bronner<br>Date: Wednesday, 02 '
#  'June 2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="sess7.html"><button type="button" class="btn btn-light-blue '
#  'btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '  <!-- Card -->\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="sess6.html"><img class="card-img-top" '
#  'src="img/events/sess6/sess6.png" alt="data science"></a>\r\n'
#  '      <a href="sess6.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="sess6.html"><h6 class="card-title">Breaking the Social Media '
#  'Prism</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p>Speaker: Chris Bail<br>Date: Wednesday, 19 May, 2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="sess6.html"><button type="button" class="btn btn-light-blue '
#  'btn-md">Read more</button></a>\r\n'
#  '\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '  </div>\r\n'
#  '  <!-- Card -->\r\n'
#  '</div>\r\n'
#  '\r\n'
#  '\r\n'
#  '\r\n'
#  '<div class="col-xs-12 col-sm-6 col-md-4 portfolio-item filter-spring">\r\n'
#  '  <!-- Card -->\r\n'
#  '  <div class="card mb-4">\r\n'
#  '\r\n'
#  '    <!--Card image-->\r\n'
#  '    <div class="view overlay">\r\n'
#  '      <a href="sess5.html"><img class="card-img-top" '
#  'src="img/events/sess5/sess5.png" alt="data science"></a>\r\n'
#  '      <a href="sess5.html">\r\n'
#  '        <div class="mask rgba-white-slight"></div>\r\n'
#  '      </a>\r\n'
#  '    </div>\r\n'
#  '\r\n'
#  '    <!--Card content-->\r\n'
#  '    <div class="card-body">\r\n'
#  '\r\n'
#  '      <!--Title-->\r\n'
#  '      <a href="sess5.html"><h6 class="card-title">Using Public Video Cameras '
#  'to Detect Racial Distancing on City Streets</h6></a>\r\n'
#  '      <!--Text-->\r\n'
#  '      <p class="card-text">Speaker: Dr. Melissa Sands <br>Date: Wednesday, '
#  '05 May 2021</p>\r\n'
#  '      <!-- Provides extra visual weight and identifies the primary action in '
#  'a set of buttons -->\r\n'
#  '      <a href="sess5.html"><button type="button" class="btn btn-light-blue '
# ...
#  "embeddings['responseEmbedding'].arraySync();\r\n"
#  '\r\n'
#  '          let scores = [];\r\n'
#  '          // compute the dotProduct of each query and response pair.\r\n'
#  '          for (let i = 0; i < embed_responses.length; i++) {\r\n'
#  '            scores.push(dotProduct(embed_query, embed_responses[i]));\r\n'
#  '            if (i == embed_responses.length-1){\r\n'
#  '              // After finished computing the score, hide the loading dots '
#  'again\r\n'
#  '              document.getElementById("loading_dots").style.display = '
#  "'none';\r\n"
#  '            }\r\n'
#  '          }    \r\n'
#  '\r\n'
#  '          var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i '
#  ': iMax, 0);\r\n'
#  '\r\n'
#  '          console.log(scores);\r\n'
#  '          console.log(tf.getBackend());\r\n'
#  '\r\n'
#  '          if (scores[max_idx] < 4) {\r\n'
#  '            chosen_response = "Sorry, I can\'t respond to that query for '
#  'now. Please do reach out directly through the form on this website to '
#  'discuss your query with our team.";\r\n'
#  '          } else {\r\n'
#  "            chosen_response = input['responses'][max_idx];\r\n"
#  '          }\r\n'
#  '\r\n'
#  '          // Show the output\r\n'
#  "          answerDiv.style.display = 'inline-block';\r\n"
#  "          answerDiv.style.color = 'white';\r\n"
#  '\r\n'
#  '          answerDiv.innerHTML = chosen_response;\r\n'
#  '          output_timeout = setTimeout(function(){ \r\n'
#  '            answerDiv.innerHTML = "";\r\n'
#  '          }, chosen_response.length*55);\r\n'
#  '        \r\n'
#  '        };\r\n'
#  '\r\n'
#  '        // Qlue-related Model\r\n'
#  '        \r\n'
#  '        // Given a model, a query (i.e. "What is his current job"), and\r\n'
#  '        // an array of responses (["He is doing great.", "He is currently '
#  'working at X."]),\r\n'
#  '        // returns responses ranked by best reply.\r\n'
#  '\r\n'
#  '        //What is the benefits of participating?\r\n'
#  '        const process_qlue = async () => {\r\n'
#  '          var qlue_query = query.value.toLowerCase();\r\n'
#  '\r\n'
#  '          qlue_query = qlue_query.replace(" benefits","")\r\n'
#  '          qlue_query = qlue_query.replace(" qlie","")\r\n'
#  '\r\n'
#  '          const model = await modelUSE;\r\n'
#  '          const input = {\r\n'
#  '            queries: [qlue_query],\r\n'
#  '            responses: ["The benefits and advantages to participate is to '
#  'have your research exposed to a wider audience and get more diverse '
#  'feedback, as well as to learn of new research and approaches in data science '
#  'implemented by others in the field."\r\n'
#  '                ]\r\n'
#  '          };\r\n'
#  '\r\n'
#  '          const embeddings  = await model.embed(input);\r\n'
#  '          const embed_query = '
#  "embeddings['queryEmbedding'].arraySync()[0];\r\n"
#  '          const embed_responses = '
#  "embeddings['responseEmbedding'].arraySync();\r\n"
#  '\r\n'
#  '          let scores = [];\r\n'
#  '          // compute the dotProduct of each query and response pair.\r\n'
#  '          for (let i = 0; i < embed_responses.length; i++) {\r\n'
#  '            scores.push(dotProduct(embed_query, embed_responses[i]));\r\n'
#  '            if (i == embed_responses.length-1){\r\n'
#  '              // After finished computing the score, hide the loading dots '
#  'again\r\n'
#  '              document.getElementById("loading_dots").style.display = '
#  "'none';\r\n"
#  '            }\r\n'
#  '          }    \r\n'
#  '\r\n'
#  '          var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i '
#  ': iMax, 0);\r\n'
#  '\r\n'
#  '          console.log(scores);\r\n'
#  '          console.log(tf.getBackend());\r\n'
#  '\r\n'
#  '          if (scores[max_idx] < 4) {\r\n'
#  '            chosen_response = "Sorry, I can\'t respond to that query for '
#  'now. Please do reach out directly through the form on this website to '
#  'discuss your query with our team.";\r\n'
#  '          } else {\r\n'
#  "            chosen_response = input['responses'][max_idx];\r\n"
#  '          }\r\n'
#  '\r\n'
#  '          // Show the output\r\n'
#  "          answerDiv.style.display = 'inline-block';\r\n"
#  "          answerDiv.style.color = 'white';\r\n"
#  '\r\n'
#  '          answerDiv.innerHTML = chosen_response;\r\n'
#  '          output_timeout = setTimeout(function(){ \r\n'
#  '            answerDiv.innerHTML = "";\r\n'
#  '          }, chosen_response.length*55);\r\n'
#  '        \r\n'
#  '        };\r\n'
#  '\r\n'
#  '\r\n'
#  '        // WB-related Model\r\n'
#  '        \r\n'
#  '        // Given a model, a query (i.e. "What is his current job"), and\r\n'
#  '        // an array of responses (["He is doing great.", "He is currently '
#  'working at X."]),\r\n'
#  '        // returns responses ranked by best reply.\r\n'
#  '\r\n'
#  '        //When is it \r\n'
#  '        const process_wb = async () => {\r\n'
#  '          var wb_query = query.value.toLowerCase();\r\n'
#  '\r\n'
#  '          wb_query = wb_query.replace(" take place","")\r\n'
#  '          wb_query = wb_query.replace(" organised","")\r\n'
#  '\r\n'
#  '          const model = await modelUSE;\r\n'
#  '          const input = {\r\n'
#  '            queries: [wb_query],\r\n'
#  '            responses: ["During covid times, the seminar series will take '
#  'place online and is intended to be organised throughout the academic year. '
#  'During normal times, the event will be organised in different insitutions '
#  'within the CIVICA network."\r\n'
#  '                 \r\n'
#  '                ]\r\n'
#  '          };\r\n'
#  '\r\n'
#  '          const embeddings  = await model.embed(input);\r\n'
#  '          const embed_query = '
#  "embeddings['queryEmbedding'].arraySync()[0];\r\n"
#  '          const embed_responses = '
#  "embeddings['responseEmbedding'].arraySync();\r\n"
#  '\r\n'
#  '          let scores = [];\r\n'
#  '          // compute the dotProduct of each query and response pair.\r\n'
#  '          for (let i = 0; i < embed_responses.length; i++) {\r\n'
#  '            scores.push(dotProduct(embed_query, embed_responses[i]));\r\n'
#  '            if (i == embed_responses.length-1){\r\n'
#  '              // After finished computing the score, hide the loading dots '
#  'again\r\n'
#  '              document.getElementById("loading_dots").style.display = '
#  "'none';\r\n"
#  '            }\r\n'
#  '          }    \r\n'
#  '\r\n'
#  '          var max_idx = scores.reduce((iMax, x, i, arr) => x > arr[iMax] ? i '
#  ': iMax, 0);\r\n'
#  '\r\n'
#  '          console.log(scores);\r\n'
#  '          console.log(tf.getBackend());\r\n'
#  '\r\n'
#  '          if (scores[max_idx] < 4) {\r\n'
#  '            chosen_response = "Sorry, I can\'t respond to that query for '
#  'now. Please do reach out directly through the form on this website to '
#  'discuss your query with our team;"\r\n'
#  '          } else {\r\n'
#  "            chosen_response = input['responses'][max_idx];\r\n"
#  '          }\r\n'
#  '\r\n'
#  '          // Show the output\r\n'
#  "          answerDiv.style.display = 'inline-block';\r\n"
#  "          answerDiv.style.color = 'white';\r\n"
#  '\r\n'
#  '          answerDiv.innerHTML = chosen_response;\r\n'
#  '          output_timeout = setTimeout(function(){ \r\n'
#  '            answerDiv.innerHTML = "";\r\n'
#  '          }, chosen_response.length*55);\r\n'
#  '        \r\n'
#  '        };\r\n'
#  '\r\n'
#  '\r\n'
#  '        // Variable to check it is the first time load or not\r\n'
#  '        i = 0;\r\n'
#  '        i_model = 0;\r\n'
#  '\r\n'
#  '        window.onload = () => {   \r\n'
#  "          query = document.getElementById('myInput');\r\n"
#  "          search = document.getElementById('myButton');\r\n"
#  '          answerDiv  = document.getElementById("output");\r\n'
#  '\r\n'
#  '          console.log(query.value)\r\n'
#  '            \r\n'
#  "          query.addEventListener('keyup', async (event) => {\r\n"
#  "            if (event.key === 'Enter') {\r\n"
#  '              if (query.value.toLowerCase()=="hi" || '
#  'query.value.toLowerCase().includes("hello") || '
#  'query.value.toLowerCase().includes("hallo") || '
#  'query.value.toLowerCase().includes("how are you") || '
#  'query.value.toLowerCase().includes("how\'s day") || '
#  'query.value.toLowerCase().includes("what\'s up") || '
#  'query.value.toLowerCase().includes("how do you do") || '
#  'query.value.toLowerCase().includes("morning") || '
#  'query.value.toLowerCase().includes("evening") || '
#  'query.value.toLowerCase().includes("afternoon") || '
#  'query.value.toLowerCase().includes("night")) {\r\n'
#  '                if (i == 0){\r\n'
#  '                  // Hide output \r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  // Hide Assistant Description and show loading dots for '
#  'the first query\r\n'
#  '                  '
#  'document.getElementById("first_assistant_desc").style.display = \'none\';\r\n'
#  '                } else {\r\n'
#  '                  // Hide output & clear timeout output from previous '
#  'iter\r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  clearTimeout(output_timeout);\r\n'
#  '                }\r\n'
#  '\r\n'
#  '                i = i+1;\r\n'
#  '                \r\n'
#  '                chosen_response = "Thanks for greeting! We are doing great. '
#  'Hope you have a wonderful day :)";\r\n'
#  '\r\n'
#  '                // Show the output\r\n'
#  "                answerDiv.style.display = 'inline-block';\r\n"
#  "                answerDiv.style.color = 'white';\r\n"
#  '\r\n'
#  '                answerDiv.innerHTML = chosen_response;\r\n'
#  '                output_timeout = setTimeout(function(){ \r\n'
#  '                  answerDiv.innerHTML = "";\r\n'
#  '                }, chosen_response.length*55);\r\n'
#  '              } else if (query.value.toLowerCase().includes("where you '
#  'work") || query.value.toLowerCase().includes("where you works") || '
#  'query.value.toLowerCase().includes("where are you working")) {\r\n'
#  '                if (i == 0){\r\n'
#  '                  // Hide output \r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  // Hide Assistant Description and show loading dots for '
#  'the first query\r\n'
#  '                  '
#  'document.getElementById("first_assistant_desc").style.display = \'none\';\r\n'
#  '                } else {\r\n'
#  '                  // Hide output & clear timeout output from previous '
#  'iter\r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  clearTimeout(output_timeout);\r\n'
#  '                }\r\n'
#  '\r\n'
#  '                i = i+1;\r\n'
#  '                \r\n'
#  '                chosen_response = "We are working at CIVICA '
#  'institutions";\r\n'
#  '\r\n'
#  '                // Show the output\r\n'
#  "                answerDiv.style.display = 'inline-block';\r\n"
#  "                answerDiv.style.color = 'white';\r\n"
#  '\r\n'
#  '                answerDiv.innerHTML = chosen_response;\r\n'
#  '                output_timeout = setTimeout(function(){ \r\n'
#  '                  answerDiv.innerHTML = "";\r\n'
#  '                }, chosen_response.length*55);\r\n'
#  '              } else if (query.value.toLowerCase().includes("meaning of '
#  'life")) {\r\n'
#  '                if (i == 0){\r\n'
#  '                  // Hide output \r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  // Hide Assistant Description and show loading dots for '
#  'the first query\r\n'
#  '                  '
#  'document.getElementById("first_assistant_desc").style.display = \'none\';\r\n'
#  '                } else {\r\n'
#  '                  // Hide output & clear timeout output from previous '
#  'iter\r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  clearTimeout(output_timeout);\r\n'
#  '                }\r\n'
#  '\r\n'
#  '                i = i+1;\r\n'
#  '\r\n'
#  '                chosen_response = "It\'s 42. Or if you don\'t like it '
#  'quantified, to attend the CIVICA seminar series on data science :)";\r\n'
#  '\r\n'
#  '                // Show the output\r\n'
#  "                answerDiv.style.display = 'inline-block';\r\n"
#  "                answerDiv.style.color = 'white';\r\n"
#  '\r\n'
#  '                answerDiv.innerHTML = chosen_response;\r\n'
#  '                output_timeout = setTimeout(function(){ \r\n'
#  '                  answerDiv.innerHTML = "";\r\n'
#  '                }, chosen_response.length*55);\r\n'
#  '              } else if (query.value.toLowerCase().includes("first intern")) '
#  '{\r\n'
#  '                if (i == 0){\r\n'
#  '                  // Hide output \r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  // Hide Assistant Description and show loading dots for '
#  'the first query\r\n'
#  '                  '
#  'document.getElementById("first_assistant_desc").style.display = \'none\';\r\n'
#  '                } else {\r\n'
#  '                  // Hide output & clear timeout output from previous '
#  'iter\r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  clearTimeout(output_timeout);\r\n'
#  '                }\r\n'
#  '\r\n'
#  '                i = i+1;\r\n'
#  '\r\n'
#  '                chosen_response = "Sorry I don\'t understand your '
#  'query.";\r\n'
#  '\r\n'
#  '                // Show the output\r\n'
#  "                answerDiv.style.display = 'inline-block';\r\n"
#  "                answerDiv.style.color = 'white';\r\n"
#  '\r\n'
#  '                answerDiv.innerHTML = chosen_response;\r\n'
#  '                output_timeout = setTimeout(function(){ \r\n'
#  '                  answerDiv.innerHTML = "";\r\n'
#  '                }, chosen_response.length*55);\r\n'
#  '              } else {\r\n'
#  '                console.log(i)\r\n'
#  '                if (i_model == 0){\r\n'
#  '                  // Hide output \r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  // Hide Assistant Description and show loading dots for '
#  'the first query\r\n'
#  '                  '
#  'document.getElementById("first_assistant_desc").style.display = \'none\';\r\n'
#  '                  document.getElementById("loading_dots").style.display = '
#  "'inline-block';\r\n"
#  '                  modelUSE = use.loadQnA();\r\n'
#  '                } else {\r\n'
#  '                  // Hide output & clear timeout output from previous '
#  'iter\r\n'
#  "                  answerDiv.style.display = 'none';\r\n"
#  '                  clearTimeout(output_timeout);\r\n'
#  '                }\r\n'
#  '\r\n'
#  '                i_model = i_model+1;\r\n'
#  '\r\n'
#  '                // Currently only supports Web version for AI personal '
#  'assistant, because of the precision issue (16 vs 32 bit) using WebGL backend '
#  'and CPU backend is too slow. \r\n'
#  "                tf.setBackend('webgl');\r\n"
#  '                if (query.value.toLowerCase().includes(" traveloka") || '
#  'query.value.toLowerCase().includes(" tvlk") || '
#  'query.value.toLowerCase().includes(" trvloka") || '
#  'query.value.toLowerCase().includes(" trave")) {\r\n'
#  '                  process_trave();\r\n'
#  '                } else if (query.value.toLowerCase().includes(" tokopedia") '
#  '|| query.value.toLowerCase().includes(" toped") || '
#  'query.value.toLowerCase().includes(" tkpd") || '
#  'query.value.toLowerCase().includes(" tkopedia")){\r\n'
#  '                  process_tokped();\r\n'
#  '                } else if (query.value.toLowerCase().includes(" do-it") || '
#  'query.value.toLowerCase().includes(" do it") || '
#  'query.value.toLowerCase().includes(" doit")){\r\n'
#  '                  process_doit();\r\n'
#  '                } else if (query.value.toLowerCase().includes(" qlue") || '
#  '(query.value.toLowerCase().includes(" qlie"))) {\r\n'
#  '                  process_qlue();\r\n'
#  '                } else if (query.value.toLowerCase().includes(" world bank") '
#  '|| (query.value.toLowerCase().includes(" wb"))) {\r\n'
#  '                  process_wb();\r\n'
#  '                }else {\r\n'
#  '                  process_general();\r\n'
#  '                }\r\n'
#  '              }\r\n'
#  '            }\r\n'
#  '          });\r\n'
#  '        };\r\n'
#  '\r\n'
#  '      </script>\r\n'
#  '\r\n'
#  '</div></form></div></section></div></div></section></main></body>')

# %% [markdown]
# **Are there any `<h1>` tags in this page?**

# %%
sel.css('h1').get()
# Out:
# '<h1 class="mb-4 pb-0">CIVICA<br><span>Data Science</span> Seminar Series</h1>'

# %% [markdown]
# What about `<h2>` tags?

# %%
sel.css('h2').getall()
# Out:
# ['<h2>Seminar Schedule</h2>',
#  '<h2>Partner Institutions</h2>',
#  '<h2>Gallery</h2>',
#  '<h2>F.A.Q </h2>',
#  '<h2>Newsletter</h2>',
#  '<h2>Contact Us</h2>']

# %% [markdown]
# If you care just about the **first** `<h2>` tag, you can use the `.get()` method instead of `.getall()`:

# %%
sel.css("h2").get()
# Out:
# '<h2>Seminar Schedule</h2>'

# %% [markdown]
# **How to get the text from a tag:**

# %%
sel.css("h2 ::text").get()
# Out:
# 'Seminar Schedule'

# %% [markdown]
# **How to get the text of tags returned by the `.css()` method?**
#
# You can also use `::text` on each tag element within the CSS selector returned by the `css()` method.

# %%
# Pure Python way
all_h2_tags = sel.css("h2 ::text").getall()
all_h2_texts = []

for tag in all_h2_tags:
    all_h2_texts.append(tag)

all_h2_texts
# Out:
# ['Seminar Schedule',
#  'Partner Institutions',
#  'Gallery',
#  'F.A.Q ',
#  'Newsletter',
#  'Contact Us']

# %% [markdown]
# **Consider using [list comprehension](https://www.w3schools.com/python/python_lists_comprehension.asp) for a cleaner code:**

# %%
# one-liner way
all_h2_texts = [tag.get() for tag in sel.css("h2 ::text")]
all_h2_texts
# Out:
# ['Seminar Schedule',
#  'Partner Institutions',
#  'Gallery',
#  'F.A.Q ',
#  'Newsletter',
#  'Contact Us']

# %% [markdown]
# 💡 **IMPORTANT TIPS:**
#
# - Make it a habit in the next couple of weeks to every now and then, right-click on a webpage and select "Inspect" (or "Inspect Element") to explore how the HTML is structured. This will help you understand how to use CSS selectors to extract the data you need.
# - Tag names and ` ::text` are just the tip of the iceberg. Read about other CSS selectors [here](https://www.w3schools.com/cssref/css_selectors.asp).
# - Bookmark the [Scrapy Selectors documentation page](https://docs.scrapy.org/en/latest/topics/selectors.html) and revisit it whenever you need to. Practice using different CSS selectors to extract data from the HTML.

# %% [markdown]
# # Part III: Your turn!
#
# Let's make this a dynamic and interactive lecture.

# %% [markdown]
# 🎯 **ACTION POINTS**
#
# 1. Go to the [Data Science Seminar series](https://socialdatascience.network/index.html#schedule) website and inspect the page (mouse right-click + Inspect) and find the way to the name of the first event on the page.
#
# 3. Write down the "directions" inside the HTML file to reach the event title. For example, maybe you will find that:
#
#     > _The first event title is inside a \<html\> ➡️ \<div\> ➡️ \<div\> ➡️ \<h3\> tag_.
#
#     Write it in the markdown cell below:

# %% [markdown]
# _Delete this line and write your answer here_
#
# > _The first event title is inside a \<html\> ➡️ \<body\> ➡️ \<div\> ➡️\<div\> ➡️\<div\> ➡️\<div\> ➡️\<div\> ➡️\<a\> ➡️ \<h6\> tag_.

# %% [markdown]
# 4. Now, use the skill that you have just learned to scrape the names of ALL events. Save them all to a list.

# %%
# Delete this line and replace it with your code
all_titles = [get_title(card) for card in cards]
all_titles
# Out:
# ['Misinformation exposure beyond traditional feeds: Evidence from a WhatsApp deactivation experiment in Brazil',
#  'Promoting the systematic use of real-world data and real-world evidence for digital health technologies across Europe: A consensus framework',
#  'Data science for the Sustainable Development Goals: the case of food security',
#  'CentralBankRoBERTa: A Fine-Tuned Large Language Model for Central Bank Communications',
#  'The Evolution of the Climate Discourse on Twitter: Polarization, Hypocrisy, and the Musk Takeover',
#  'The Handbook of Computational Social Science for Policy',
#  'Artificial Intelligence, Algorithmic Recommendations and Competition',
#  'Exploring A New Model of Industry/Academic Collaboration: the U.S. 2020 Facebook and Instagram Election Study',
#  'Using Multimodal Neural Networks to Better Understand How Voters Process Audiovisual Information',
#  "Models, mathematics, and data science: how to make sure we're answering the right questions",
#  'CIVICA Conference on European Polarisation',
#  'New Faces of Bias in Online Platforms',
#  'Introducing the Online Harms Observatory: AI powered mapping of online abuse in real-time',
#  'Using Open Source Data Streams and Surveys to Improve Our Understanding of Elections',
#  'Does Epistemic Vice Explain Corporate Misconduct?',
#  'Becoming a data scientist: what it means to put data to work',
#  'The Making of a French Migration Crisis',
#  'A New Approach to Visualizing Spatial Exposure Data for Comparing Earthquakes',
#  'Modeling Sustainable Development from the Bottom Up',
#  'Internet Communities and the French Presidential Election',
#  'The Science of Success: Quantifying Outcomes in Social System',
#  'Embedding Regression: Models for Context-Specific Description and Inference',
#  'Information and Irregular Migration: Evidence from a Field Experiment in Nigeria',
#  'Adjusting for Confounding with Text Matching',
#  'What is Data Feminist?',
#  'The Principles of Collective Learning',
#  "More Than Words: How Political Rhetoric Shapes Voters' Affect and Evluation",
#  'Serendipity or Confinement? Deconstructing Algorithmic Recommendation',
#  'Framing a Protest: Determinants and Effects of Visual Frames',
#  'Understanding Beautiful Places with AI',
#  'Incentives and Covid-19 Vaccination Uptake',
#  'The Art of Quantitative Editing',
#  'Breaking the Social Media Prism',
#  'Using Public Video Cameras to Detect Racial Distancing on City Streets',
#  'How to Detect Fake News Before It Is Written',
#  'Negotiating with AI: Fairness in the Labor Market',
#  'Tracking Covid-19 with the Financial Times',
#  'Police Diversity to Prevent Violence: Does It Work?',
#  'Data Science in the Time of Covid and What Happens After']

# %% [markdown]
# 5. Do the same with the dates of the events and speaker names and save them to separate lists.

# %%
# Delete this line and replace it with your code
all_dates = []
for card in cards:
    # Get the card text
    card_text = card.css('.card-body p.card-text').get()
    #print("Card Text:", card_text)  # Add debug statement
    date_text = card.xpath('.//br/following-sibling::text()').get()
    # Append the date to the list
    all_dates.append(date_text.strip() if date_text else None)

all_dates
# Out:
# ['Date: Wednesday, 07 February 2024',
#  'Date: Wednesday, 22 November 2023',
#  'Date: Wednesday, 18 October 2023',
#  'Date: Wednesday, 27 September 2023',
#  'Date: Wednesday, 13 September 2023',
#  'Date: Wednesday, 31 May 2023',
#  'Date: Wednesday, 03 May 2023',
#  'Date: Wednesday, 19 April 2023',
#  'Date: Wednesday, 22 March 2023',
#  'Date: Wednesday, 08 March 2023',
#  'Date: Wednesday, 15 February 2023',
#  'Date: Wednesday, 08 February 2023',
#  'Date: Wednesday, 11 January 2023',
#  'Date: Wednesday, 02 November 2022',
#  'Date: Wednesday, 19 October 2022',
#  'Date: Wednesday, 14 September 2022',
#  'Date: Wednesday, 15 June 2022',
#  'Date: Wednesday, 01 June 2022',
#  'Date: Wednesday, 04 May 2022',
#  'Date: Wednesday, 20 April 2022',
#  'Date: Wednesday, 09 March 2022',
#  'Date: Wednesday, 23 February 2022',
#  'Date: Wednesday, 09 February 2022',
#  'Date: Wednesday, 26 January 2022',
#  'Date: Wednesday, 12 January 2022',
#  'Date: Wednesday, 1 December 2021',
#  'Date: Wednesday, 3 November 2021',
#  'Date: Wednesday, 20 October 2021',
#  'Date: Wednesday, 06 October 2021',
#  'Date: Wednesday, 22 September, 2021',
#  'Date: Wednesday, 08 September 2021',
#  'Date: Wednesday, 02 June 2021',
#  'Date: Wednesday, 19 May, 2021',
#  'Date: Wednesday, 05 May 2021',
#  'Date: Wednesday, 21 April 2021',
#  'Date: Wednesday, 07 April, 2021',
#  'Date: Wednesday, 24 March 2021',
#  'Date: Wednesday, 17 March 2021',
#  'Date: Wednesday, 24 February, 2021']

# %% [markdown]
# 6. Combine all of these the lists into a pandas data frame and save it to a CSV file.

# %%
# Delete this line and replace it with your code
import pandas as pd

# Combine all_titles and all_dates into a DataFrame
df = pd.DataFrame({
    'Title': all_titles,
    'Date': all_dates
})

# Display the DataFrame
print(df.head())
# Out:
#                                                Title  \
# 0  Misinformation exposure beyond traditional fee...
# 1  Promoting the systematic use of real-world dat...
# 2  Data science for the Sustainable Development G...
# 3  CentralBankRoBERTa: A Fine-Tuned Large Languag...
# 4  The Evolution of the Climate Discourse on Twit...
#
#                                  Date
# 0   Date: Wednesday, 07 February 2024
# 1   Date: Wednesday, 22 November 2023
# 2    Date: Wednesday, 18 October 2023
# 3  Date: Wednesday, 27 September 2023
# 4  Date: Wednesday, 13 September 2023

# %%
# Save the DataFrame to a CSV file
df.to_csv('take_home_tasks_week_4.csv', index=False)

# %% [markdown]
# 7. Double-check that the CSV file was created correctly by opening it using pandas. Then convert the columns to appropriate data types.

# %%
# Delete this line and replace it with your code
check = pd.read_csv('take_home_tasks_week_4.csv')
check.head()
# Out:
#                                                Title  \
# 0  Misinformation exposure beyond traditional fee...
# 1  Promoting the systematic use of real-world dat...
# 2  Data science for the Sustainable Development G...
# 3  CentralBankRoBERTa: A Fine-Tuned Large Languag...
# 4  The Evolution of the Climate Discourse on Twit...
#
#                                  Date
# 0   Date: Wednesday, 07 February 2024
# 1   Date: Wednesday, 22 November 2023
# 2    Date: Wednesday, 18 October 2023
# 3  Date: Wednesday, 27 September 2023
# 4  Date: Wednesday, 13 September 2023

# %% [markdown]
# # Part IV: Why convert the scraped data to a data frame?
#
# If time allows, we will play around with the data frame in pandas to learn a few other tricks.
